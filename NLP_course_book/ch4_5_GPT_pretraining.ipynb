# %% [markdown]
# # Chapter 4,5 of course book

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import json
import stanza
from utills import MultiHeadAttention, GELU

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("Success: Using Apple M2 GPU Acceleration")
else:
    device = torch.device("cpu")
    print("Using CPU (Slow)")
# Out:
# Success: Using Apple M2 GPU Acceleration

# %% [markdown]
# Load text

# %%
with open("torah.txt", "r", encoding="utf-8") as f:
    text = f.read()

tokens_text = json.load(open("output/text_stanza.json", "r", encoding="utf-8"))

vocab = sorted(set(tokens_text))
VOCAB_SIZE = len(vocab)
print(f"Vocabulary size: {VOCAB_SIZE}")
word2idx = {token: idx for idx, token in enumerate(vocab)}
idx2word = {idx: token for idx, token in enumerate(vocab)}
# Out:
# Vocabulary size: 9109

# %% [markdown]
# Load emmbeddings

# %%
emb_tensor = None
state = torch.load("output/word2vec_model_stanza_short.pth", map_location=device)
if isinstance(state, dict):
    for key in (
        "in_embed.weight",
        "in_embed.weight",
        "out_embed.weight",
        "embeddings.weight",
        "embedding.weight",
        "encoder.weight",
    ):
        if (
            key in state
            and isinstance(state[key], torch.Tensor)
            and state[key].dim() == 2
        ):
            if state[key].size(0) == VOCAB_SIZE:
                emb_tensor = state[key]
                break

    if emb_tensor is None:
        for k, v in state.items():
            if (
                isinstance(v, torch.Tensor)
                and v.dim() == 2
                and v.size(0) == vocab_size
            ):
                emb_tensor = v
                break

if emb_tensor is None:
    raise RuntimeError(
        "Couldn't find a 2D embedding tensor matching VOCAB_SIZE in the saved state_dict."
    )
emb_tensor = emb_tensor.to(device)
print(f"Loaded embedding tensor of shape: {emb_tensor.shape}")
# Out:
# Loaded embedding tensor of shape: torch.Size([9109, 100])

# %%
GPT_CONFIG = {
    "vocab_size": VOCAB_SIZE,  # Vocabulary size
    "context_length": 256,  # Context length
    "emb_dim": emb_tensor.shape[1],  # Embedding dimension
    "n_heads": 10,  # Number of attention heads
    "n_layers": 12,  # Number of layers
    "drop_rate": 0.1,  # Dropout rate
    "qkv_bias": False,  # Query-Key-Value bias
}

# %%
class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        var = x.var(dim=-1, keepdim=True, unbiased=False)
        norm_x = (x - mean) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift

class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]),
            GELU(),
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]),
        )

    def forward(self, x):
        return self.layers(x)

# %%
class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.att = MultiHeadAttention(
            d_in=cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"],
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"],
        )
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])

    def forward(self, x):
        # Shortcut connection for attention block
        shortcut = x
        x = self.norm1(x)
        x = self.att(x)  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        # Shortcut connection for feed forward block
        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        return x

# %%
class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])

        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])]
        )

        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(cfg["emb_dim"], cfg["vocab_size"], bias=False)

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)
        pos_embeds = self.pos_emb(torch.arange(seq_len, device=in_idx.device))
        x = tok_embeds + pos_embeds  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits

# %% [markdown]
# create the model

# %%
model = GPTModel(GPT_CONFIG).to(device)

# %% [markdown]
# generating text

# %%
def generate_text_simple(model, idx, max_new_tokens, context_size):
    # idx is (batch, n_tokens) array of indices in the current context
    for _ in range(max_new_tokens):
        
        # Crop current context if it exceeds the supported context size
        # E.g., if LLM supports only 5 tokens, and the context size is 10
        # then only the last 5 tokens are used as context
        idx_cond = idx[:, -context_size:]
        
        # Get the predictions
        with torch.no_grad():
            logits = model(idx_cond)
        
        # Focus only on the last time step
        # (batch, n_tokens, vocab_size) becomes (batch, vocab_size)
        logits = logits[:, -1, :]  

        # Apply softmax to get probabilities
        probas = torch.softmax(logits, dim=-1)  # (batch, vocab_size)

        # Get the idx of the vocab entry with the highest probability value
        idx_next = torch.argmax(probas, dim=-1, keepdim=True)  # (batch, 1)

        # Append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch, n_tokens+1)

    return idx

# %% [markdown]
# create stanza tokenizer

# %%
nlp = stanza.Pipeline(
    lang="he", processors="tokenize,mwt", device=device  
)
# Out:
# 2026-01-28 12:33:33 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.11.0.json: 436kB [00:00, 11.3MB/s]
# 2026-01-28 12:33:33 INFO: Downloaded file to /Users/erannovak/stanza_resources/resources.json
# 2026-01-28 12:33:33 INFO: Loading these models for language: he (Hebrew):
# =================================
# | Processor | Package           |
# ---------------------------------
# | tokenize  | combined_nocharlm |
# | mwt       | combined          |
# =================================
#
# 2026-01-28 12:33:33 INFO: Using device: mps
# 2026-01-28 12:33:33 INFO: Loading: tokenize
# 2026-01-28 12:33:33 INFO: Loading: mwt
# 2026-01-28 12:33:33 INFO: Done loading processors!

# %%
class My_Stanza_Tokenizer:
    def __init__(self, nlp=nlp):
        self.nlp = nlp

    def tokenize(self, input_text, word2idx=word2idx):
        doc = self.nlp(input_text)
        tokens = [word.text for sent in doc.sentences for word in sent.words]
        return [word2idx[token] for token in tokens if token in word2idx]

    def encode(self, input_tokens, word2idx=word2idx):
        # return a 1-D list of token ids (no batch dim)
        if isinstance(input_tokens, str):
            doc = self.nlp(input_tokens)
            tokens = [word.text for sent in doc.sentences for word in sent.words]
            return [word2idx[t] for t in tokens if t in word2idx]
        if isinstance(input_tokens, (list, tuple)):
            if len(input_tokens) == 0:
                return []
            # if already ints (token ids), return as list
            if isinstance(input_tokens[0], int):
                return list(input_tokens)
            # otherwise treat as token strings
            return [word2idx[token] for token in input_tokens if token in word2idx]
        raise TypeError("encode() expects str or list/tuple")

    def decode(self, indices, idx2word=idx2word):
        if isinstance(indices, torch.Tensor):
            indices = indices.squeeze(0).tolist()
        decoded =  [idx2word[idx] for idx in indices if idx in idx2word]
        return [' '.join(i) for i in decoded] if isinstance(decoded[0], list) else ' '.join(decoded)

# %%
tokenizer = My_Stanza_Tokenizer(nlp)
start_context = "כי ידע כל לב איש"
encoded_context = tokenizer.tokenize(start_context, word2idx)
print(encoded_context)
print(tokenizer.decode(encoded_context, idx2word))
# Out:
# [4119, 3014, 4140, 4389, 292]
# כי ידע כל לב איש

# %%
start_context = "כי ידע כל לב איש"
doc = nlp(start_context)
tokens = [word.text for sent in doc.sentences for word in sent.words]
print(tokens)
# Out:
# ['כי', 'ידע', 'כל', 'לב', 'איש']

# %%
encoded = [word2idx[token] for token in tokens if token in word2idx]
print(encoded)
encoded_tensor = torch.tensor(encoded, dtype=torch.long, device=device).unsqueeze(0)
# Out:
# [4119, 3014, 4140, 4389, 292]

# %%
model.eval() # disable dropout

out = generate_text_simple(
    model=model,
    idx=encoded_tensor, 
    max_new_tokens=6, 
    context_size=GPT_CONFIG["context_length"]
)

print("Output:", out)
print("Output length:", len(out[0]))
# Out:
# Output: tensor([[4119, 3014, 4140, 4389,  292, 7283,  342, 5170, 3065, 2453, 7639]],
#        device='mps:0')
# Output length: 11

# %%
print("Generated tokens:", [idx2word[idx.item()] for idx in out[0]])
# Out:
# Generated tokens: ['כי', 'ידע', 'כל', 'לב', 'איש', 'צדיו', 'אלהם', 'מות', 'יובא', 'חדשי', 'קרכ']

# %% [markdown]
# Training text completion
# Data set and data loader

# %%
TRAIN_RATIO = 0.9

# %%
class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, word2idx)
        assert (
            len(token_ids) > max_length
        ), "Number of tokenized inputs must at least be equal to max_length+1"

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i : i + max_length]
            target_chunk = token_ids[i + 1 : i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(
    txt,
    batch_size=4,
    max_length=256,
    stride=128,
    shuffle=True,
    drop_last=True,
    num_workers=0,
):

    tokenizer = My_Stanza_Tokenizer(nlp)

    # If caller passed already-tokenized list of tokens (strings) or list of ids, handle it:
    if isinstance(txt, (list, tuple)):
        # if list of token strings, convert to ids; if list of ints, keep
        if len(txt) == 0:
            raise ValueError("Empty input 'txt'")
        if isinstance(txt[0], int):
            token_ids = list(txt)
        else:
            token_ids = tokenizer.encode(txt, word2idx)
    else:
        # txt is a single string
        token_ids = tokenizer.encode(txt, word2idx)

    if len(token_ids) <= max_length:
        raise ValueError(f"token_ids too short for max_length={max_length} (len={len(token_ids)})")

    # pass the token id list into the dataset (GPTDatasetV1 calls tokenizer.encode internally,
    # but now we can pass token ids directly by converting dataset to accept lists or by
    # creating a small wrapper — simplest: pass the original token list and let GPTDatasetV1 call encode)
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
    )

    return dataloader

# %%
# token and id's functions
def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text)
    encoded_tensor = torch.tensor(encoded).unsqueeze(0)  # add batch dimension
    return encoded_tensor


def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0)  # remove batch dimension
    return tokenizer.decode(flat.tolist())

# %% [markdown]
# training and validation data

# %%
train_ratio = TRAIN_RATIO
split_idx = int(len(tokens_text) * train_ratio)
train_data = tokens_text[:split_idx]
val_data = tokens_text[split_idx:]
print(f"Train data size: {len(train_data)} tokens")
print("train data sample:", train_data[:5])
print(f"Validation data size: {len(val_data)} tokens")
# Out:
# Train data size: 108688 tokens
# train data sample: ['ב', 'ראשית', 'ברא', 'אלהים', 'את']
# Validation data size: 12077 tokens

# %%
train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG["context_length"],
    stride=GPT_CONFIG["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0,
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG["context_length"],
    stride=GPT_CONFIG["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0,
)
# print("Train loader:")
# for x, y in train_loader:
#     print(x.shape, y.shape)

# print("\nValidation loader:")
# for x, y in val_loader:
#     print(x.shape, y.shape)

# %% [markdown]
# Loss functions

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(
        logits.flatten(0, 1), target_batch.flatten()
    )
    return loss


def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.0
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # Reduce the number of batches to match the total number of batches in the data loader
        # if num_batches exceeds the number of batches in the data loader
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %% [markdown]
# test loss functions

# %%
with torch.no_grad():  # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: 9.30222293565858
# Validation loss: 9.294546683629354

# %% [markdown]
# training loop

# %% [markdown]
# helper function

# %%
def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded, max_new_tokens=50, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(
            train_loader, model, device, num_batches=eval_iter
        )
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss

# %%
def train_model_simple(
    model,
    train_loader,
    val_loader,
    optimizer,
    device,
    num_epochs,
    eval_freq,
    eval_iter,
    start_context,
    tokenizer,
):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode

        for input_batch, target_batch in train_loader:
            optimizer.zero_grad()  # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward()  # Calculate loss gradients
            optimizer.step()  # Update model weights using loss gradients
            tokens_seen += input_batch.numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter
                )
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(
                    f"Ep {epoch+1} (Step {global_step:06d}): "
                    f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}"
                )

        # Print a sample text after each epoch
        generate_and_print_sample(model, tokenizer, device, start_context)

    return train_losses, val_losses, track_tokens_seen

# %% [markdown]
# training loop

# %%
torch.manual_seed(123)
start_text = "וילכו בני ישראל אל המקום"
doc = nlp(start_text)
tokens = [word.text for sent in doc.sentences for word in sent.words]
encoded = [word2idx[token] for token in tokens if token in word2idx]
start_context = torch.tensor(encoded, dtype=torch.long, device=device).unsqueeze(0)
print(start_context)
# Out:
# tensor([[2223,  948, 3937,  330, 1445, 5720]], device='mps:0')

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)
tokenizer = My_Stanza_Tokenizer(nlp)
num_epochs = 50

train_losses, val_losses, tokens_seen = train_model_simple(
    model,
    train_loader,
    val_loader,
    optimizer,
    device,
    num_epochs=num_epochs,
    eval_freq=5,
    eval_iter=5,
    start_context= "וילכו בני ישראל אל המקום",
    tokenizer=tokenizer,
)
# Out:
# Ep 1 (Step 000000): Train loss 9.110, Val loss 9.065
# Ep 1 (Step 000005): Train loss 8.421, Val loss 8.470
# Ep 1 (Step 000010): Train loss 8.225, Val loss 8.164
# Ep 1 (Step 000015): Train loss 7.921, Val loss 7.941
# Ep 1 (Step 000020): Train loss 7.678, Val loss 7.740
# Ep 1 (Step 000025): Train loss 7.559, Val loss 7.553
# Ep 1 (Step 000030): Train loss 7.235, Val loss 7.365
# Ep 1 (Step 000035): Train loss 7.157, Val loss 7.177
# Ep 1 (Step 000040): Train loss 6.921, Val loss 7.009
# Ep 1 (Step 000045): Train loss 6.779, Val loss 6.861
# Ep 1 (Step 000050): Train loss 6.751, Val loss 6.732
# Ep 1 (Step 000055): Train loss 6.552, Val loss 6.623
# Ep 1 (Step 000060): Train loss 6.399, Val loss 6.513
# Ep 1 (Step 000065): Train loss 6.380, Val loss 6.432
# Ep 1 (Step 000070): Train loss 6.230, Val loss 6.361
# Ep 1 (Step 000075): Train loss 6.114, Val loss 6.296
# Ep 1 (Step 000080): Train loss 6.219, Val loss 6.239
# Ep 1 (Step 000085): Train loss 6.157, Val loss 6.193
# Ep 1 (Step 000090): Train loss 6.177, Val loss 6.153
# Ep 1 (Step 000095): Train loss 5.866, Val loss 6.126
# Ep 1 (Step 000100): Train loss 6.004, Val loss 6.103
# Ep 1 (Step 000105): Train loss 5.989, Val loss 6.094
# Ep 1 (Step 000110): Train loss 5.912, Val loss 6.074
# Ep 1 (Step 000115): Train loss 5.945, Val loss 6.062
# Ep 1 (Step 000120): Train loss 6.029, Val loss 6.048
# Ep 1 (Step 000125): Train loss 5.768, Val loss 6.051
# Ep 1 (Step 000130): Train loss 5.951, Val loss 6.038
# Ep 1 (Step 000135): Train loss 5.862, Val loss 6.029
# Ep 1 (Step 000140): Train loss 5.760, Val loss 6.022
# Ep 1 (Step 000145): Train loss 5.985, Val loss 6.007
# Ep 1 (Step 000150): Train loss 5.833, Val loss 6.008
# Ep 1 (Step 000155): Train loss 5.995, Val loss 5.981
# Ep 1 (Step 000160): Train loss 5.801, Val loss 5.964
# Ep 1 (Step 000165): Train loss 5.689, Val loss 5.946
# Ep 1 (Step 000170): Train loss 5.672, Val loss 5.940
# Ep 1 (Step 000175): Train loss 5.844, Val loss 5.941
# Ep 1 (Step 000180): Train loss 5.917, Val loss 5.932
# Ep 1 (Step 000185): Train loss 5.860, Val loss 5.930
# Ep 1 (Step 000190): Train loss 5.775, Val loss 5.929
# Ep 1 (Step 000195): Train loss 5.684, Val loss 5.900
# Ep 1 (Step 000200): Train loss 5.715, Val loss 5.866
# Ep 1 (Step 000205): Train loss 5.684, Val loss 5.842
# Ep 1 (Step 000210): Train loss 5.717, Val loss 5.831
# וילכו בני ישראל אל ה מקום ו ה ו ו את ה ו ו ו ו ו ו את ה ו ו ו יאמר ו את ה ו ו ו ו ו ו את ה ו ו ו ו את ה ו ו ו ו את ה ו ו ו ו ו ו ו ו ו
# Ep 2 (Step 000215): Train loss 5.863, Val loss 5.829
# Ep 2 (Step 000220): Train loss 5.575, Val loss 5.838
# Ep 2 (Step 000225): Train loss 5.602, Val loss 5.837
# Ep 2 (Step 000230): Train loss 5.752, Val loss 5.844
# Ep 2 (Step 000235): Train loss 5.765, Val loss 5.830
# Ep 2 (Step 000240): Train loss 5.838, Val loss 5.837
# Ep 2 (Step 000245): Train loss 5.688, Val loss 5.835
# Ep 2 (Step 000250): Train loss 5.668, Val loss 5.838
# Ep 2 (Step 000255): Train loss 5.573, Val loss 5.838
# Ep 2 (Step 000260): Train loss 5.675, Val loss 5.844
# Ep 2 (Step 000265): Train loss 5.817, Val loss 5.843
# Ep 2 (Step 000270): Train loss 5.724, Val loss 5.852
# Ep 2 (Step 000275): Train loss 5.523, Val loss 5.838
# Ep 2 (Step 000280): Train loss 5.598, Val loss 5.822
# Ep 2 (Step 000285): Train loss 5.565, Val loss 5.822
# Ep 2 (Step 000290): Train loss 5.683, Val loss 5.814
# Ep 2 (Step 000295): Train loss 5.711, Val loss 5.797
# Ep 2 (Step 000300): Train loss 5.638, Val loss 5.784
# Ep 2 (Step 000305): Train loss 5.586, Val loss 5.772
# Ep 2 (Step 000310): Train loss 5.545, Val loss 5.763
# Ep 2 (Step 000315): Train loss 5.659, Val loss 5.752
# Ep 2 (Step 000320): Train loss 5.671, Val loss 5.745
# Ep 2 (Step 000325): Train loss 5.554, Val loss 5.750
# Ep 2 (Step 000330): Train loss 5.577, Val loss 5.731
# Ep 2 (Step 000335): Train loss 5.603, Val loss 5.720
# Ep 2 (Step 000340): Train loss 5.278, Val loss 5.706
# Ep 2 (Step 000345): Train loss 5.556, Val loss 5.715
# Ep 2 (Step 000350): Train loss 5.518, Val loss 5.715
# Ep 2 (Step 000355): Train loss 5.825, Val loss 5.718
# Ep 2 (Step 000360): Train loss 5.584, Val loss 5.721
# Ep 2 (Step 000365): Train loss 5.392, Val loss 5.741
# Ep 2 (Step 000370): Train loss 5.671, Val loss 5.727
# Ep 2 (Step 000375): Train loss 5.650, Val loss 5.722
# Ep 2 (Step 000380): Train loss 5.505, Val loss 5.739
# Ep 2 (Step 000385): Train loss 5.472, Val loss 5.746
# Ep 2 (Step 000390): Train loss 5.373, Val loss 5.746
# Ep 2 (Step 000395): Train loss 5.404, Val loss 5.736
# Ep 2 (Step 000400): Train loss 5.257, Val loss 5.731
# Ep 2 (Step 000405): Train loss 5.459, Val loss 5.739
# Ep 2 (Step 000410): Train loss 5.430, Val loss 5.713
# Ep 2 (Step 000415): Train loss 5.390, Val loss 5.694
# Ep 2 (Step 000420): Train loss 5.517, Val loss 5.680
# וילכו בני ישראל אל ה מקום . ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ו
# Ep 3 (Step 000425): Train loss 5.544, Val loss 5.670
# Ep 3 (Step 000430): Train loss 5.424, Val loss 5.676
# Ep 3 (Step 000435): Train loss 5.402, Val loss 5.687
# Ep 3 (Step 000440): Train loss 5.384, Val loss 5.695
# Ep 3 (Step 000445): Train loss 5.259, Val loss 5.684
# Ep 3 (Step 000450): Train loss 5.412, Val loss 5.666
# Ep 3 (Step 000455): Train loss 5.453, Val loss 5.653
# Ep 3 (Step 000460): Train loss 5.526, Val loss 5.660
# Ep 3 (Step 000465): Train loss 5.590, Val loss 5.679
# Ep 3 (Step 000470): Train loss 5.446, Val loss 5.657
# Ep 3 (Step 000475): Train loss 5.293, Val loss 5.632
# Ep 3 (Step 000480): Train loss 5.191, Val loss 5.632
# Ep 3 (Step 000485): Train loss 5.634, Val loss 5.641
# Ep 3 (Step 000490): Train loss 5.515, Val loss 5.639
# Ep 3 (Step 000495): Train loss 5.318, Val loss 5.624
# Ep 3 (Step 000500): Train loss 5.221, Val loss 5.624
# Ep 3 (Step 000505): Train loss 5.205, Val loss 5.618
# Ep 3 (Step 000510): Train loss 5.312, Val loss 5.611
# Ep 3 (Step 000515): Train loss 5.338, Val loss 5.605
# Ep 3 (Step 000520): Train loss 5.411, Val loss 5.615
# Ep 3 (Step 000525): Train loss 5.378, Val loss 5.623
# Ep 3 (Step 000530): Train loss 5.293, Val loss 5.620
# Ep 3 (Step 000535): Train loss 5.321, Val loss 5.616
# Ep 3 (Step 000540): Train loss 5.444, Val loss 5.597
# Ep 3 (Step 000545): Train loss 5.224, Val loss 5.609
# Ep 3 (Step 000550): Train loss 5.330, Val loss 5.634
# Ep 3 (Step 000555): Train loss 5.189, Val loss 5.638
# Ep 3 (Step 000560): Train loss 5.461, Val loss 5.629
# Ep 3 (Step 000565): Train loss 5.351, Val loss 5.616
# Ep 3 (Step 000570): Train loss 5.268, Val loss 5.631
# Ep 3 (Step 000575): Train loss 5.399, Val loss 5.615
# Ep 3 (Step 000580): Train loss 5.333, Val loss 5.615
# Ep 3 (Step 000585): Train loss 5.069, Val loss 5.632
# Ep 3 (Step 000590): Train loss 5.531, Val loss 5.645
# Ep 3 (Step 000595): Train loss 5.261, Val loss 5.638
# Ep 3 (Step 000600): Train loss 5.252, Val loss 5.624
# Ep 3 (Step 000605): Train loss 5.277, Val loss 5.598
# Ep 3 (Step 000610): Train loss 5.385, Val loss 5.575
# Ep 3 (Step 000615): Train loss 5.280, Val loss 5.570
# Ep 3 (Step 000620): Train loss 5.195, Val loss 5.571
# Ep 3 (Step 000625): Train loss 5.226, Val loss 5.573
# Ep 3 (Step 000630): Train loss 5.253, Val loss 5.571
# Ep 3 (Step 000635): Train loss 5.175, Val loss 5.584
# וילכו בני ישראל אל ה מקום . ו יאמר יהוה אל משה ו יאמר יהוה אל משה ו יאמר יהוה אל משה ו יאמר יהוה אל משה ו יאמר יהוה אל משה ו יאמר יהוה אל משה ו יאמר יהוה אל משה ו יאמר יהוה אל משה ו יאמר יהוה אל משה ו יאמר יהוה אל
# Ep 4 (Step 000640): Train loss 5.213, Val loss 5.603
# Ep 4 (Step 000645): Train loss 5.189, Val loss 5.597
# Ep 4 (Step 000650): Train loss 5.319, Val loss 5.589
# Ep 4 (Step 000655): Train loss 5.353, Val loss 5.595
# Ep 4 (Step 000660): Train loss 5.310, Val loss 5.583
# Ep 4 (Step 000665): Train loss 5.272, Val loss 5.565
# Ep 4 (Step 000670): Train loss 5.187, Val loss 5.578
# Ep 4 (Step 000675): Train loss 5.378, Val loss 5.568
# Ep 4 (Step 000680): Train loss 5.262, Val loss 5.564
# Ep 4 (Step 000685): Train loss 5.191, Val loss 5.587
# Ep 4 (Step 000690): Train loss 5.175, Val loss 5.584
# Ep 4 (Step 000695): Train loss 5.285, Val loss 5.575
# Ep 4 (Step 000700): Train loss 5.241, Val loss 5.582
# Ep 4 (Step 000705): Train loss 5.279, Val loss 5.597
# Ep 4 (Step 000710): Train loss 5.218, Val loss 5.581
# Ep 4 (Step 000715): Train loss 5.157, Val loss 5.580
# Ep 4 (Step 000720): Train loss 5.287, Val loss 5.557
# Ep 4 (Step 000725): Train loss 5.286, Val loss 5.552
# Ep 4 (Step 000730): Train loss 5.310, Val loss 5.542
# Ep 4 (Step 000735): Train loss 5.100, Val loss 5.535
# Ep 4 (Step 000740): Train loss 5.055, Val loss 5.559
# Ep 4 (Step 000745): Train loss 5.098, Val loss 5.555
# Ep 4 (Step 000750): Train loss 5.014, Val loss 5.555
# Ep 4 (Step 000755): Train loss 5.218, Val loss 5.553
# Ep 4 (Step 000760): Train loss 5.039, Val loss 5.556
# Ep 4 (Step 000765): Train loss 5.232, Val loss 5.530
# Ep 4 (Step 000770): Train loss 5.047, Val loss 5.532
# Ep 4 (Step 000775): Train loss 5.179, Val loss 5.519
# Ep 4 (Step 000780): Train loss 4.925, Val loss 5.509
# Ep 4 (Step 000785): Train loss 5.084, Val loss 5.510
# Ep 4 (Step 000790): Train loss 5.082, Val loss 5.507
# Ep 4 (Step 000795): Train loss 5.162, Val loss 5.538
# Ep 4 (Step 000800): Train loss 5.377, Val loss 5.526
# Ep 4 (Step 000805): Train loss 5.077, Val loss 5.517
# Ep 4 (Step 000810): Train loss 5.163, Val loss 5.520
# Ep 4 (Step 000815): Train loss 5.089, Val loss 5.500
# Ep 4 (Step 000820): Train loss 5.195, Val loss 5.502
# Ep 4 (Step 000825): Train loss 5.059, Val loss 5.503
# Ep 4 (Step 000830): Train loss 5.010, Val loss 5.515
# Ep 4 (Step 000835): Train loss 5.138, Val loss 5.508
# Ep 4 (Step 000840): Train loss 5.252, Val loss 5.501
# Ep 4 (Step 000845): Train loss 5.022, Val loss 5.519
# וילכו בני ישראל אל ה מקום . ו יאמר יהוה אל משה אל משה ו את ה עם ו את ה זה ו את ה עם ו את ה כהן ו את ה עם ו את ה עם ו את ה עם ו את ה זה ו את ה עם ו את ה עם ו את
# Ep 5 (Step 000850): Train loss 4.941, Val loss 5.541
# Ep 5 (Step 000855): Train loss 5.106, Val loss 5.536
# Ep 5 (Step 000860): Train loss 5.141, Val loss 5.518
# Ep 5 (Step 000865): Train loss 5.180, Val loss 5.516
# Ep 5 (Step 000870): Train loss 5.121, Val loss 5.519
# Ep 5 (Step 000875): Train loss 5.053, Val loss 5.544
# Ep 5 (Step 000880): Train loss 5.075, Val loss 5.516
# Ep 5 (Step 000885): Train loss 5.158, Val loss 5.515
# Ep 5 (Step 000890): Train loss 4.929, Val loss 5.515
# Ep 5 (Step 000895): Train loss 4.858, Val loss 5.519
# Ep 5 (Step 000900): Train loss 5.166, Val loss 5.517
# Ep 5 (Step 000905): Train loss 5.133, Val loss 5.516
# Ep 5 (Step 000910): Train loss 5.038, Val loss 5.510
# Ep 5 (Step 000915): Train loss 4.907, Val loss 5.520
# Ep 5 (Step 000920): Train loss 5.216, Val loss 5.513
# Ep 5 (Step 000925): Train loss 5.157, Val loss 5.501
# Ep 5 (Step 000930): Train loss 4.977, Val loss 5.516
# Ep 5 (Step 000935): Train loss 5.034, Val loss 5.513
# Ep 5 (Step 000940): Train loss 4.897, Val loss 5.513
# Ep 5 (Step 000945): Train loss 4.859, Val loss 5.510
# Ep 5 (Step 000950): Train loss 5.122, Val loss 5.502
# Ep 5 (Step 000955): Train loss 4.919, Val loss 5.485
# Ep 5 (Step 000960): Train loss 4.983, Val loss 5.491
# Ep 5 (Step 000965): Train loss 5.150, Val loss 5.499
# Ep 5 (Step 000970): Train loss 4.854, Val loss 5.497
# Ep 5 (Step 000975): Train loss 4.999, Val loss 5.484
# Ep 5 (Step 000980): Train loss 4.999, Val loss 5.488
# Ep 5 (Step 000985): Train loss 5.107, Val loss 5.510
# Ep 5 (Step 000990): Train loss 4.964, Val loss 5.448
# Ep 5 (Step 000995): Train loss 4.935, Val loss 5.409
# Ep 5 (Step 001000): Train loss 4.986, Val loss 5.406
# Ep 5 (Step 001005): Train loss 4.852, Val loss 5.411
# Ep 5 (Step 001010): Train loss 4.945, Val loss 5.433
# Ep 5 (Step 001015): Train loss 4.774, Val loss 5.456
# Ep 5 (Step 001020): Train loss 5.005, Val loss 5.449
# Ep 5 (Step 001025): Train loss 4.975, Val loss 5.445
# Ep 5 (Step 001030): Train loss 5.053, Val loss 5.461
# Ep 5 (Step 001035): Train loss 5.153, Val loss 5.471
# Ep 5 (Step 001040): Train loss 5.107, Val loss 5.492
# Ep 5 (Step 001045): Train loss 4.912, Val loss 5.473
# Ep 5 (Step 001050): Train loss 5.022, Val loss 5.482
# Ep 5 (Step 001055): Train loss 5.172, Val loss 5.482
# וילכו בני ישראל אל ה מקום ה כהן ו את ה ארץ ו את ה ארץ ו את ה ארץ ו את ה ארץ ה כהן ו את ה כהן ו את ה ארץ ו את ה ארץ ו את ה כהן ו את ה כהן ו את ה ארץ ו את ה ארץ ו את
# Ep 6 (Step 001060): Train loss 4.880, Val loss 5.475
# Ep 6 (Step 001065): Train loss 4.886, Val loss 5.465
# Ep 6 (Step 001070): Train loss 5.101, Val loss 5.457
# Ep 6 (Step 001075): Train loss 4.979, Val loss 5.463
# Ep 6 (Step 001080): Train loss 5.031, Val loss 5.459
# Ep 6 (Step 001085): Train loss 5.194, Val loss 5.448
# Ep 6 (Step 001090): Train loss 5.044, Val loss 5.450
# Ep 6 (Step 001095): Train loss 5.014, Val loss 5.442
# Ep 6 (Step 001100): Train loss 4.866, Val loss 5.447
# Ep 6 (Step 001105): Train loss 5.092, Val loss 5.463
# Ep 6 (Step 001110): Train loss 4.952, Val loss 5.449
# Ep 6 (Step 001115): Train loss 4.874, Val loss 5.434
# Ep 6 (Step 001120): Train loss 4.946, Val loss 5.439
# Ep 6 (Step 001125): Train loss 4.652, Val loss 5.441
# Ep 6 (Step 001130): Train loss 4.893, Val loss 5.441
# Ep 6 (Step 001135): Train loss 5.002, Val loss 5.428
# Ep 6 (Step 001140): Train loss 4.818, Val loss 5.407
# Ep 6 (Step 001145): Train loss 4.899, Val loss 5.409
# Ep 6 (Step 001150): Train loss 4.887, Val loss 5.424
# Ep 6 (Step 001155): Train loss 4.884, Val loss 5.424
# Ep 6 (Step 001160): Train loss 4.862, Val loss 5.411
# Ep 6 (Step 001165): Train loss 4.894, Val loss 5.395
# Ep 6 (Step 001170): Train loss 4.867, Val loss 5.396
# Ep 6 (Step 001175): Train loss 5.091, Val loss 5.433
# Ep 6 (Step 001180): Train loss 4.942, Val loss 5.441
# Ep 6 (Step 001185): Train loss 4.618, Val loss 5.437
# Ep 6 (Step 001190): Train loss 5.053, Val loss 5.449
# Ep 6 (Step 001195): Train loss 4.955, Val loss 5.475
# Ep 6 (Step 001200): Train loss 4.959, Val loss 5.467
# Ep 6 (Step 001205): Train loss 4.719, Val loss 5.443
# Ep 6 (Step 001210): Train loss 4.714, Val loss 5.440
# Ep 6 (Step 001215): Train loss 4.518, Val loss 5.468
# Ep 6 (Step 001220): Train loss 4.946, Val loss 5.480
# Ep 6 (Step 001225): Train loss 5.138, Val loss 5.468
# Ep 6 (Step 001230): Train loss 4.891, Val loss 5.456
# Ep 6 (Step 001235): Train loss 5.073, Val loss 5.423
# Ep 6 (Step 001240): Train loss 4.729, Val loss 5.422
# Ep 6 (Step 001245): Train loss 4.851, Val loss 5.438
# Ep 6 (Step 001250): Train loss 4.843, Val loss 5.455
# Ep 6 (Step 001255): Train loss 4.696, Val loss 5.456
# Ep 6 (Step 001260): Train loss 4.694, Val loss 5.428
# Ep 6 (Step 001265): Train loss 4.881, Val loss 5.428
# Ep 6 (Step 001270): Train loss 4.812, Val loss 5.458
# וילכו בני ישראל אל ה מקום ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן
# Ep 7 (Step 001275): Train loss 4.896, Val loss 5.458
# Ep 7 (Step 001280): Train loss 4.643, Val loss 5.457
# Ep 7 (Step 001285): Train loss 4.894, Val loss 5.443
# Ep 7 (Step 001290): Train loss 4.856, Val loss 5.450
# Ep 7 (Step 001295): Train loss 4.603, Val loss 5.442
# Ep 7 (Step 001300): Train loss 4.838, Val loss 5.454
# Ep 7 (Step 001305): Train loss 4.786, Val loss 5.460
# Ep 7 (Step 001310): Train loss 4.802, Val loss 5.450
# Ep 7 (Step 001315): Train loss 4.959, Val loss 5.430
# Ep 7 (Step 001320): Train loss 4.854, Val loss 5.422
# Ep 7 (Step 001325): Train loss 4.765, Val loss 5.420
# Ep 7 (Step 001330): Train loss 4.702, Val loss 5.396
# Ep 7 (Step 001335): Train loss 4.753, Val loss 5.412
# Ep 7 (Step 001340): Train loss 4.713, Val loss 5.441
# Ep 7 (Step 001345): Train loss 4.866, Val loss 5.432
# Ep 7 (Step 001350): Train loss 4.793, Val loss 5.411
# Ep 7 (Step 001355): Train loss 4.744, Val loss 5.408
# Ep 7 (Step 001360): Train loss 4.688, Val loss 5.419
# Ep 7 (Step 001365): Train loss 4.850, Val loss 5.458
# Ep 7 (Step 001370): Train loss 4.840, Val loss 5.417
# Ep 7 (Step 001375): Train loss 4.631, Val loss 5.392
# Ep 7 (Step 001380): Train loss 4.887, Val loss 5.409
# Ep 7 (Step 001385): Train loss 4.893, Val loss 5.418
# Ep 7 (Step 001390): Train loss 4.807, Val loss 5.438
# Ep 7 (Step 001395): Train loss 4.622, Val loss 5.439
# Ep 7 (Step 001400): Train loss 4.695, Val loss 5.441
# Ep 7 (Step 001405): Train loss 4.455, Val loss 5.451
# Ep 7 (Step 001410): Train loss 4.750, Val loss 5.417
# Ep 7 (Step 001415): Train loss 4.781, Val loss 5.394
# Ep 7 (Step 001420): Train loss 4.636, Val loss 5.409
# Ep 7 (Step 001425): Train loss 4.786, Val loss 5.418
# Ep 7 (Step 001430): Train loss 4.714, Val loss 5.420
# Ep 7 (Step 001435): Train loss 4.644, Val loss 5.404
# Ep 7 (Step 001440): Train loss 4.810, Val loss 5.440
# Ep 7 (Step 001445): Train loss 4.792, Val loss 5.425
# Ep 7 (Step 001450): Train loss 4.635, Val loss 5.407
# Ep 7 (Step 001455): Train loss 4.750, Val loss 5.386
# Ep 7 (Step 001460): Train loss 4.801, Val loss 5.409
# Ep 7 (Step 001465): Train loss 4.532, Val loss 5.405
# Ep 7 (Step 001470): Train loss 4.364, Val loss 5.409
# Ep 7 (Step 001475): Train loss 4.497, Val loss 5.417
# Ep 7 (Step 001480): Train loss 4.734, Val loss 5.400
# וילכו בני ישראל אל ה מקום אשר צוה יהוה אל משה לאמר . ו את ה ארץ מצרים ו את ה ארץ אשר צוה יהוה אל משה ו את ה כהן את ה ארץ אשר צוה יהוה אל משה ו את ה ארץ אשר צוה יהוה אל משה אל משה אל משה ו את ה ארץ
# Ep 8 (Step 001485): Train loss 4.527, Val loss 5.393
# Ep 8 (Step 001490): Train loss 4.695, Val loss 5.398
# Ep 8 (Step 001495): Train loss 4.617, Val loss 5.421
# Ep 8 (Step 001500): Train loss 4.609, Val loss 5.447
# Ep 8 (Step 001505): Train loss 4.634, Val loss 5.441
# Ep 8 (Step 001510): Train loss 4.710, Val loss 5.425
# Ep 8 (Step 001515): Train loss 4.579, Val loss 5.392
# Ep 8 (Step 001520): Train loss 4.627, Val loss 5.405
# Ep 8 (Step 001525): Train loss 4.622, Val loss 5.426
# Ep 8 (Step 001530): Train loss 4.714, Val loss 5.408
# Ep 8 (Step 001535): Train loss 4.555, Val loss 5.384
# Ep 8 (Step 001540): Train loss 4.655, Val loss 5.373
# Ep 8 (Step 001545): Train loss 4.344, Val loss 5.371
# Ep 8 (Step 001550): Train loss 4.789, Val loss 5.384
# Ep 8 (Step 001555): Train loss 4.503, Val loss 5.362
# Ep 8 (Step 001560): Train loss 4.812, Val loss 5.356
# Ep 8 (Step 001565): Train loss 4.596, Val loss 5.368
# Ep 8 (Step 001570): Train loss 4.569, Val loss 5.377
# Ep 8 (Step 001575): Train loss 4.619, Val loss 5.377
# Ep 8 (Step 001580): Train loss 4.605, Val loss 5.406
# Ep 8 (Step 001585): Train loss 4.540, Val loss 5.431
# Ep 8 (Step 001590): Train loss 4.514, Val loss 5.403
# Ep 8 (Step 001595): Train loss 4.693, Val loss 5.383
# Ep 8 (Step 001600): Train loss 4.798, Val loss 5.363
# Ep 8 (Step 001605): Train loss 4.805, Val loss 5.366
# Ep 8 (Step 001610): Train loss 4.521, Val loss 5.375
# Ep 8 (Step 001615): Train loss 4.747, Val loss 5.393
# Ep 8 (Step 001620): Train loss 4.392, Val loss 5.385
# Ep 8 (Step 001625): Train loss 4.618, Val loss 5.366
# Ep 8 (Step 001630): Train loss 4.557, Val loss 5.372
# Ep 8 (Step 001635): Train loss 4.654, Val loss 5.391
# Ep 8 (Step 001640): Train loss 4.680, Val loss 5.373
# Ep 8 (Step 001645): Train loss 4.602, Val loss 5.367
# Ep 8 (Step 001650): Train loss 4.590, Val loss 5.380
# Ep 8 (Step 001655): Train loss 4.578, Val loss 5.392
# Ep 8 (Step 001660): Train loss 4.614, Val loss 5.409
# Ep 8 (Step 001665): Train loss 4.596, Val loss 5.414
# Ep 8 (Step 001670): Train loss 4.634, Val loss 5.408
# Ep 8 (Step 001675): Train loss 4.624, Val loss 5.391
# Ep 8 (Step 001680): Train loss 4.514, Val loss 5.395
# Ep 8 (Step 001685): Train loss 4.565, Val loss 5.402
# Ep 8 (Step 001690): Train loss 4.522, Val loss 5.392
# Ep 8 (Step 001695): Train loss 4.529, Val loss 5.384
# וילכו בני ישראל אל ה מקום . ו יאמר יהוה אל משה אל משה אל משה אל משה אל משה אל משה ו יאמר יהוה אל משה אל משה אל משה אל משה אל משה אל משה אל משה אל משה ו ו יאמר יהוה אל משה אל משה ו יאמר יהוה אל משה אל משה
# Ep 9 (Step 001700): Train loss 4.391, Val loss 5.382
# Ep 9 (Step 001705): Train loss 4.676, Val loss 5.406
# Ep 9 (Step 001710): Train loss 4.570, Val loss 5.409
# Ep 9 (Step 001715): Train loss 4.560, Val loss 5.405
# Ep 9 (Step 001720): Train loss 4.187, Val loss 5.429
# Ep 9 (Step 001725): Train loss 4.708, Val loss 5.417
# Ep 9 (Step 001730): Train loss 4.402, Val loss 5.423
# Ep 9 (Step 001735): Train loss 4.400, Val loss 5.402
# Ep 9 (Step 001740): Train loss 4.267, Val loss 5.412
# Ep 9 (Step 001745): Train loss 4.546, Val loss 5.410
# Ep 9 (Step 001750): Train loss 4.686, Val loss 5.410
# Ep 9 (Step 001755): Train loss 4.618, Val loss 5.424
# Ep 9 (Step 001760): Train loss 4.564, Val loss 5.429
# Ep 9 (Step 001765): Train loss 4.446, Val loss 5.408
# Ep 9 (Step 001770): Train loss 4.416, Val loss 5.374
# Ep 9 (Step 001775): Train loss 4.537, Val loss 5.357
# Ep 9 (Step 001780): Train loss 4.376, Val loss 5.387
# Ep 9 (Step 001785): Train loss 4.373, Val loss 5.395
# Ep 9 (Step 001790): Train loss 4.330, Val loss 5.394
# Ep 9 (Step 001795): Train loss 4.631, Val loss 5.376
# Ep 9 (Step 001800): Train loss 4.497, Val loss 5.355
# Ep 9 (Step 001805): Train loss 4.379, Val loss 5.337
# Ep 9 (Step 001810): Train loss 4.528, Val loss 5.355
# Ep 9 (Step 001815): Train loss 4.314, Val loss 5.366
# Ep 9 (Step 001820): Train loss 4.521, Val loss 5.365
# Ep 9 (Step 001825): Train loss 4.555, Val loss 5.364
# Ep 9 (Step 001830): Train loss 4.533, Val loss 5.390
# Ep 9 (Step 001835): Train loss 4.225, Val loss 5.391
# Ep 9 (Step 001840): Train loss 4.468, Val loss 5.393
# Ep 9 (Step 001845): Train loss 4.261, Val loss 5.379
# Ep 9 (Step 001850): Train loss 4.298, Val loss 5.385
# Ep 9 (Step 001855): Train loss 4.502, Val loss 5.376
# Ep 9 (Step 001860): Train loss 4.412, Val loss 5.376
# Ep 9 (Step 001865): Train loss 4.519, Val loss 5.382
# Ep 9 (Step 001870): Train loss 4.361, Val loss 5.391
# Ep 9 (Step 001875): Train loss 4.421, Val loss 5.393
# Ep 9 (Step 001880): Train loss 4.271, Val loss 5.407
# Ep 9 (Step 001885): Train loss 4.465, Val loss 5.396
# Ep 9 (Step 001890): Train loss 4.332, Val loss 5.381
# Ep 9 (Step 001895): Train loss 4.500, Val loss 5.378
# Ep 9 (Step 001900): Train loss 4.246, Val loss 5.367
# Ep 9 (Step 001905): Train loss 4.385, Val loss 5.352
# וילכו בני ישראל אל ה מקום אשר על ה זה . ו ידבר יהוה אל היך ו ה כהן את ה כהן ו את ה כהן את ה כהן ו את ה כהן ו את ה כהן ו את ה כהן את ה כהן את ה כהן את ה כהן ו את ה כהן ו את
# Ep 10 (Step 001910): Train loss 4.311, Val loss 5.351
# Ep 10 (Step 001915): Train loss 4.354, Val loss 5.364
# Ep 10 (Step 001920): Train loss 4.524, Val loss 5.333
# Ep 10 (Step 001925): Train loss 4.519, Val loss 5.351
# Ep 10 (Step 001930): Train loss 4.706, Val loss 5.362
# Ep 10 (Step 001935): Train loss 4.493, Val loss 5.349
# Ep 10 (Step 001940): Train loss 4.148, Val loss 5.363
# Ep 10 (Step 001945): Train loss 4.377, Val loss 5.388
# Ep 10 (Step 001950): Train loss 4.312, Val loss 5.392
# Ep 10 (Step 001955): Train loss 4.386, Val loss 5.352
# Ep 10 (Step 001960): Train loss 4.335, Val loss 5.352
# Ep 10 (Step 001965): Train loss 4.272, Val loss 5.371
# Ep 10 (Step 001970): Train loss 4.330, Val loss 5.367
# Ep 10 (Step 001975): Train loss 4.713, Val loss 5.370
# Ep 10 (Step 001980): Train loss 4.402, Val loss 5.361
# Ep 10 (Step 001985): Train loss 4.608, Val loss 5.355
# Ep 10 (Step 001990): Train loss 4.459, Val loss 5.349
# Ep 10 (Step 001995): Train loss 4.261, Val loss 5.359
# Ep 10 (Step 002000): Train loss 4.203, Val loss 5.384
# Ep 10 (Step 002005): Train loss 4.437, Val loss 5.359
# Ep 10 (Step 002010): Train loss 4.223, Val loss 5.352
# Ep 10 (Step 002015): Train loss 4.406, Val loss 5.368
# Ep 10 (Step 002020): Train loss 4.208, Val loss 5.406
# Ep 10 (Step 002025): Train loss 4.670, Val loss 5.416
# Ep 10 (Step 002030): Train loss 4.138, Val loss 5.369
# Ep 10 (Step 002035): Train loss 4.459, Val loss 5.349
# Ep 10 (Step 002040): Train loss 4.141, Val loss 5.362
# Ep 10 (Step 002045): Train loss 4.294, Val loss 5.391
# Ep 10 (Step 002050): Train loss 4.108, Val loss 5.371
# Ep 10 (Step 002055): Train loss 4.390, Val loss 5.354
# Ep 10 (Step 002060): Train loss 4.440, Val loss 5.345
# Ep 10 (Step 002065): Train loss 4.144, Val loss 5.361
# Ep 10 (Step 002070): Train loss 3.981, Val loss 5.395
# Ep 10 (Step 002075): Train loss 4.335, Val loss 5.396
# Ep 10 (Step 002080): Train loss 4.328, Val loss 5.361
# Ep 10 (Step 002085): Train loss 4.468, Val loss 5.372
# Ep 10 (Step 002090): Train loss 4.268, Val loss 5.396
# Ep 10 (Step 002095): Train loss 4.136, Val loss 5.401
# Ep 10 (Step 002100): Train loss 4.339, Val loss 5.390
# Ep 10 (Step 002105): Train loss 4.251, Val loss 5.383
# Ep 10 (Step 002110): Train loss 4.321, Val loss 5.376
# Ep 10 (Step 002115): Train loss 4.177, Val loss 5.371
# וילכו בני ישראל אל ה מקום אשר צוה יהוה אל משה אל משה ו את ה ארץ ה ארץ . ו את ה ארץ אשר צוה יהוה אל משה ו את ה עם ו את ה ארץ אשר על ה ארץ אשר על ה ארץ אשר על ה ארץ ו את ה ארץ אשר על ה
# Ep 11 (Step 002120): Train loss 4.318, Val loss 5.382
# Ep 11 (Step 002125): Train loss 4.243, Val loss 5.382
# Ep 11 (Step 002130): Train loss 4.288, Val loss 5.355
# Ep 11 (Step 002135): Train loss 4.193, Val loss 5.329
# Ep 11 (Step 002140): Train loss 4.261, Val loss 5.326
# Ep 11 (Step 002145): Train loss 4.382, Val loss 5.349
# Ep 11 (Step 002150): Train loss 4.283, Val loss 5.384
# Ep 11 (Step 002155): Train loss 4.272, Val loss 5.379
# Ep 11 (Step 002160): Train loss 4.065, Val loss 5.405
# Ep 11 (Step 002165): Train loss 4.221, Val loss 5.356
# Ep 11 (Step 002170): Train loss 4.196, Val loss 5.374
# Ep 11 (Step 002175): Train loss 4.249, Val loss 5.397
# Ep 11 (Step 002180): Train loss 4.236, Val loss 5.366
# Ep 11 (Step 002185): Train loss 4.326, Val loss 5.354
# Ep 11 (Step 002190): Train loss 4.267, Val loss 5.379
# Ep 11 (Step 002195): Train loss 4.133, Val loss 5.370
# Ep 11 (Step 002200): Train loss 4.456, Val loss 5.342
# Ep 11 (Step 002205): Train loss 4.163, Val loss 5.372
# Ep 11 (Step 002210): Train loss 3.918, Val loss 5.393
# Ep 11 (Step 002215): Train loss 3.972, Val loss 5.365
# Ep 11 (Step 002220): Train loss 4.123, Val loss 5.352
# Ep 11 (Step 002225): Train loss 3.854, Val loss 5.352
# Ep 11 (Step 002230): Train loss 3.763, Val loss 5.364
# Ep 11 (Step 002235): Train loss 4.162, Val loss 5.342
# Ep 11 (Step 002240): Train loss 4.004, Val loss 5.337
# Ep 11 (Step 002245): Train loss 4.144, Val loss 5.350
# Ep 11 (Step 002250): Train loss 4.143, Val loss 5.351
# Ep 11 (Step 002255): Train loss 4.194, Val loss 5.343
# Ep 11 (Step 002260): Train loss 4.140, Val loss 5.339
# Ep 11 (Step 002265): Train loss 4.256, Val loss 5.349
# Ep 11 (Step 002270): Train loss 4.086, Val loss 5.364
# Ep 11 (Step 002275): Train loss 4.215, Val loss 5.384
# Ep 11 (Step 002280): Train loss 4.212, Val loss 5.371
# Ep 11 (Step 002285): Train loss 3.967, Val loss 5.381
# Ep 11 (Step 002290): Train loss 4.092, Val loss 5.387
# Ep 11 (Step 002295): Train loss 3.863, Val loss 5.395
# Ep 11 (Step 002300): Train loss 4.165, Val loss 5.395
# Ep 11 (Step 002305): Train loss 4.208, Val loss 5.375
# Ep 11 (Step 002310): Train loss 4.057, Val loss 5.364
# Ep 11 (Step 002315): Train loss 4.226, Val loss 5.387
# Ep 11 (Step 002320): Train loss 4.270, Val loss 5.379
# Ep 11 (Step 002325): Train loss 4.149, Val loss 5.335
# Ep 11 (Step 002330): Train loss 3.944, Val loss 5.332
# וילכו בני ישראל אל ה מקום . ו יאמר יהוה אל משה אל משה אל משה אל משה אל משה אל משה ו אל משה אל משה לאמר ו אל משה אל משה אל משה אל משה אל משה אל משה לאמר . ו אל משה אל משה אל משה אל משה אל משה אל משה
# Ep 12 (Step 002335): Train loss 3.956, Val loss 5.348
# Ep 12 (Step 002340): Train loss 3.845, Val loss 5.355
# Ep 12 (Step 002345): Train loss 4.119, Val loss 5.357
# Ep 12 (Step 002350): Train loss 4.192, Val loss 5.374
# Ep 12 (Step 002355): Train loss 4.108, Val loss 5.387
# Ep 12 (Step 002360): Train loss 4.117, Val loss 5.367
# Ep 12 (Step 002365): Train loss 4.142, Val loss 5.365
# Ep 12 (Step 002370): Train loss 3.958, Val loss 5.366
# Ep 12 (Step 002375): Train loss 3.987, Val loss 5.410
# Ep 12 (Step 002380): Train loss 4.103, Val loss 5.388
# Ep 12 (Step 002385): Train loss 3.834, Val loss 5.359
# Ep 12 (Step 002390): Train loss 4.055, Val loss 5.336
# Ep 12 (Step 002395): Train loss 3.915, Val loss 5.353
# Ep 12 (Step 002400): Train loss 3.874, Val loss 5.380
# Ep 12 (Step 002405): Train loss 4.097, Val loss 5.404
# Ep 12 (Step 002410): Train loss 4.100, Val loss 5.383
# Ep 12 (Step 002415): Train loss 4.147, Val loss 5.364
# Ep 12 (Step 002420): Train loss 4.006, Val loss 5.364
# Ep 12 (Step 002425): Train loss 4.048, Val loss 5.380
# Ep 12 (Step 002430): Train loss 4.093, Val loss 5.394
# Ep 12 (Step 002435): Train loss 4.018, Val loss 5.405
# Ep 12 (Step 002440): Train loss 4.111, Val loss 5.382
# Ep 12 (Step 002445): Train loss 4.038, Val loss 5.359
# Ep 12 (Step 002450): Train loss 4.058, Val loss 5.379
# Ep 12 (Step 002455): Train loss 4.261, Val loss 5.426
# Ep 12 (Step 002460): Train loss 4.089, Val loss 5.385
# Ep 12 (Step 002465): Train loss 4.136, Val loss 5.376
# Ep 12 (Step 002470): Train loss 3.792, Val loss 5.374
# Ep 12 (Step 002475): Train loss 3.922, Val loss 5.397
# Ep 12 (Step 002480): Train loss 4.121, Val loss 5.447
# Ep 12 (Step 002485): Train loss 3.821, Val loss 5.452
# Ep 12 (Step 002490): Train loss 3.937, Val loss 5.421
# Ep 12 (Step 002495): Train loss 4.186, Val loss 5.367
# Ep 12 (Step 002500): Train loss 3.786, Val loss 5.352
# Ep 12 (Step 002505): Train loss 4.000, Val loss 5.386
# Ep 12 (Step 002510): Train loss 3.999, Val loss 5.404
# Ep 12 (Step 002515): Train loss 3.895, Val loss 5.383
# Ep 12 (Step 002520): Train loss 4.057, Val loss 5.357
# Ep 12 (Step 002525): Train loss 4.003, Val loss 5.375
# Ep 12 (Step 002530): Train loss 3.978, Val loss 5.430
# Ep 12 (Step 002535): Train loss 3.968, Val loss 5.429
# Ep 12 (Step 002540): Train loss 4.041, Val loss 5.360
# וילכו בני ישראל אל ה מקום אשר ב ו לא יאכל . ו לא תעשו את כם ו לא תעשו ו לא יאכל ו לא יאכל . ו לא יאכל לא יאכל . ו לא תעשו את כם ו לא תשא לא יאכל את כם ו לא יהיה ל כם . ו לא תגלה ל כם
# Ep 13 (Step 002545): Train loss 4.084, Val loss 5.355
# Ep 13 (Step 002550): Train loss 3.838, Val loss 5.402
# Ep 13 (Step 002555): Train loss 4.177, Val loss 5.403
# Ep 13 (Step 002560): Train loss 4.021, Val loss 5.380
# Ep 13 (Step 002565): Train loss 3.611, Val loss 5.382
# Ep 13 (Step 002570): Train loss 4.133, Val loss 5.381
# Ep 13 (Step 002575): Train loss 4.149, Val loss 5.393
# Ep 13 (Step 002580): Train loss 3.767, Val loss 5.407
# Ep 13 (Step 002585): Train loss 3.785, Val loss 5.396
# Ep 13 (Step 002590): Train loss 4.066, Val loss 5.406
# Ep 13 (Step 002595): Train loss 3.917, Val loss 5.379
# Ep 13 (Step 002600): Train loss 3.659, Val loss 5.403
# Ep 13 (Step 002605): Train loss 4.033, Val loss 5.408
# Ep 13 (Step 002610): Train loss 3.717, Val loss 5.422
# Ep 13 (Step 002615): Train loss 3.908, Val loss 5.405
# Ep 13 (Step 002620): Train loss 4.100, Val loss 5.367
# Ep 13 (Step 002625): Train loss 3.600, Val loss 5.379
# Ep 13 (Step 002630): Train loss 3.866, Val loss 5.377
# Ep 13 (Step 002635): Train loss 4.112, Val loss 5.393
# Ep 13 (Step 002640): Train loss 3.665, Val loss 5.409
# Ep 13 (Step 002645): Train loss 3.914, Val loss 5.392
# Ep 13 (Step 002650): Train loss 3.476, Val loss 5.369
# Ep 13 (Step 002655): Train loss 3.667, Val loss 5.353
# Ep 13 (Step 002660): Train loss 3.687, Val loss 5.359
# Ep 13 (Step 002665): Train loss 3.776, Val loss 5.365
# Ep 13 (Step 002670): Train loss 3.734, Val loss 5.391
# Ep 13 (Step 002675): Train loss 4.135, Val loss 5.393
# Ep 13 (Step 002680): Train loss 3.876, Val loss 5.389
# Ep 13 (Step 002685): Train loss 4.019, Val loss 5.399
# Ep 13 (Step 002690): Train loss 3.915, Val loss 5.402
# Ep 13 (Step 002695): Train loss 3.846, Val loss 5.423
# Ep 13 (Step 002700): Train loss 3.695, Val loss 5.410
# Ep 13 (Step 002705): Train loss 3.806, Val loss 5.400
# Ep 13 (Step 002710): Train loss 3.861, Val loss 5.401
# Ep 13 (Step 002715): Train loss 3.934, Val loss 5.373
# Ep 13 (Step 002720): Train loss 3.941, Val loss 5.357
# Ep 13 (Step 002725): Train loss 3.841, Val loss 5.383
# Ep 13 (Step 002730): Train loss 3.521, Val loss 5.379
# Ep 13 (Step 002735): Train loss 3.664, Val loss 5.408
# Ep 13 (Step 002740): Train loss 3.744, Val loss 5.380
# Ep 13 (Step 002745): Train loss 3.807, Val loss 5.369
# Ep 13 (Step 002750): Train loss 3.776, Val loss 5.358
# Ep 13 (Step 002755): Train loss 3.886, Val loss 5.385
# וילכו בני ישראל אל ה מקום אשר לא יאכל . ו לא יאכל לא יהיה ל כם ו לא יהיה ל כם ב יום ה ארץ מצרים . ו לא יהיה ל כם ו לא תעשו את כם ו לא יהיה ל כם ו לא יהיה ל כם . ו לא תעשו את כם ב יום
# Ep 14 (Step 002760): Train loss 3.820, Val loss 5.392
# Ep 14 (Step 002765): Train loss 3.641, Val loss 5.369
# Ep 14 (Step 002770): Train loss 3.806, Val loss 5.366
# Ep 14 (Step 002775): Train loss 3.785, Val loss 5.405
# Ep 14 (Step 002780): Train loss 3.831, Val loss 5.445
# Ep 14 (Step 002785): Train loss 3.659, Val loss 5.411
# Ep 14 (Step 002790): Train loss 3.640, Val loss 5.395
# Ep 14 (Step 002795): Train loss 3.668, Val loss 5.420
# Ep 14 (Step 002800): Train loss 3.515, Val loss 5.419
# Ep 14 (Step 002805): Train loss 3.970, Val loss 5.404
# Ep 14 (Step 002810): Train loss 3.744, Val loss 5.417
# Ep 14 (Step 002815): Train loss 3.978, Val loss 5.422
# Ep 14 (Step 002820): Train loss 3.844, Val loss 5.405
# Ep 14 (Step 002825): Train loss 3.445, Val loss 5.437
# Ep 14 (Step 002830): Train loss 3.637, Val loss 5.431
# Ep 14 (Step 002835): Train loss 3.780, Val loss 5.401
# Ep 14 (Step 002840): Train loss 3.674, Val loss 5.413
# Ep 14 (Step 002845): Train loss 3.754, Val loss 5.404
# Ep 14 (Step 002850): Train loss 3.936, Val loss 5.413
# Ep 14 (Step 002855): Train loss 3.780, Val loss 5.445
# Ep 14 (Step 002860): Train loss 4.032, Val loss 5.419
# Ep 14 (Step 002865): Train loss 3.760, Val loss 5.397
# Ep 14 (Step 002870): Train loss 3.979, Val loss 5.383
# Ep 14 (Step 002875): Train loss 3.739, Val loss 5.391
# Ep 14 (Step 002880): Train loss 3.844, Val loss 5.389
# Ep 14 (Step 002885): Train loss 3.644, Val loss 5.406
# Ep 14 (Step 002890): Train loss 3.476, Val loss 5.434
# Ep 14 (Step 002895): Train loss 3.750, Val loss 5.452
# Ep 14 (Step 002900): Train loss 3.790, Val loss 5.412
# Ep 14 (Step 002905): Train loss 3.620, Val loss 5.412
# Ep 14 (Step 002910): Train loss 3.666, Val loss 5.429
# Ep 14 (Step 002915): Train loss 3.601, Val loss 5.447
# Ep 14 (Step 002920): Train loss 3.831, Val loss 5.430
# Ep 14 (Step 002925): Train loss 3.716, Val loss 5.399
# Ep 14 (Step 002930): Train loss 3.843, Val loss 5.409
# Ep 14 (Step 002935): Train loss 3.741, Val loss 5.434
# Ep 14 (Step 002940): Train loss 3.834, Val loss 5.412
# Ep 14 (Step 002945): Train loss 3.677, Val loss 5.390
# Ep 14 (Step 002950): Train loss 3.540, Val loss 5.415
# Ep 14 (Step 002955): Train loss 3.740, Val loss 5.467
# Ep 14 (Step 002960): Train loss 3.690, Val loss 5.451
# Ep 14 (Step 002965): Train loss 3.277, Val loss 5.400
# וילכו בני ישראל אל ה מקום אשר צוה יהוה אל משה לאמר . ו בני ישראל ו בני ישראל ו בני ישראל ו אהרן ו ידבר יהוה אל משה לאמר . ו אהרן ו בני ישראל ו אהרן ו אהרן את בני ישראל ו בני ישראל את משה את ה לוים ו את בני ישראל ו
# Ep 15 (Step 002970): Train loss 3.651, Val loss 5.387
# Ep 15 (Step 002975): Train loss 3.783, Val loss 5.428
# Ep 15 (Step 002980): Train loss 3.692, Val loss 5.432
# Ep 15 (Step 002985): Train loss 3.610, Val loss 5.440
# Ep 15 (Step 002990): Train loss 3.627, Val loss 5.429
# Ep 15 (Step 002995): Train loss 3.525, Val loss 5.440
# Ep 15 (Step 003000): Train loss 3.755, Val loss 5.451
# Ep 15 (Step 003005): Train loss 3.389, Val loss 5.445
# Ep 15 (Step 003010): Train loss 3.668, Val loss 5.440
# Ep 15 (Step 003015): Train loss 3.338, Val loss 5.437
# Ep 15 (Step 003020): Train loss 3.569, Val loss 5.443
# Ep 15 (Step 003025): Train loss 3.661, Val loss 5.453
# Ep 15 (Step 003030): Train loss 3.480, Val loss 5.420
# Ep 15 (Step 003035): Train loss 3.620, Val loss 5.417
# Ep 15 (Step 003040): Train loss 3.539, Val loss 5.431
# Ep 15 (Step 003045): Train loss 3.658, Val loss 5.429
# Ep 15 (Step 003050): Train loss 3.636, Val loss 5.440
# Ep 15 (Step 003055): Train loss 3.634, Val loss 5.449
# Ep 15 (Step 003060): Train loss 3.755, Val loss 5.438
# Ep 15 (Step 003065): Train loss 3.665, Val loss 5.421
# Ep 15 (Step 003070): Train loss 3.394, Val loss 5.429
# Ep 15 (Step 003075): Train loss 3.787, Val loss 5.418
# Ep 15 (Step 003080): Train loss 3.648, Val loss 5.448
# Ep 15 (Step 003085): Train loss 3.746, Val loss 5.450
# Ep 15 (Step 003090): Train loss 3.760, Val loss 5.413
# Ep 15 (Step 003095): Train loss 3.365, Val loss 5.395
# Ep 15 (Step 003100): Train loss 3.743, Val loss 5.408
# Ep 15 (Step 003105): Train loss 3.678, Val loss 5.395
# Ep 15 (Step 003110): Train loss 3.457, Val loss 5.362
# Ep 15 (Step 003115): Train loss 3.554, Val loss 5.384
# Ep 15 (Step 003120): Train loss 3.712, Val loss 5.426
# Ep 15 (Step 003125): Train loss 3.591, Val loss 5.443
# Ep 15 (Step 003130): Train loss 3.625, Val loss 5.423
# Ep 15 (Step 003135): Train loss 3.512, Val loss 5.413
# Ep 15 (Step 003140): Train loss 3.561, Val loss 5.426
# Ep 15 (Step 003145): Train loss 3.364, Val loss 5.422
# Ep 15 (Step 003150): Train loss 3.620, Val loss 5.430
# Ep 15 (Step 003155): Train loss 3.254, Val loss 5.412
# Ep 15 (Step 003160): Train loss 3.718, Val loss 5.422
# Ep 15 (Step 003165): Train loss 3.602, Val loss 5.432
# Ep 15 (Step 003170): Train loss 3.632, Val loss 5.408
# Ep 15 (Step 003175): Train loss 3.456, Val loss 5.415
# וילכו בני ישראל אל ה מקום אשר ב ו לא יאכל יהוה אל משה אל משה אל משה אל משה אל משה לאמר . ו יאמר משה לאמר אל משה אל משה אל משה אל משה אל משה לאמר . ו יהוה אל משה אל משה אל משה אל משה אל משה אל משה אל משה
# Ep 16 (Step 003180): Train loss 3.285, Val loss 5.431
# Ep 16 (Step 003185): Train loss 3.437, Val loss 5.444
# Ep 16 (Step 003190): Train loss 3.654, Val loss 5.474
# Ep 16 (Step 003195): Train loss 3.768, Val loss 5.473
# Ep 16 (Step 003200): Train loss 3.445, Val loss 5.448
# Ep 16 (Step 003205): Train loss 3.504, Val loss 5.455
# Ep 16 (Step 003210): Train loss 3.283, Val loss 5.456
# Ep 16 (Step 003215): Train loss 3.727, Val loss 5.455
# Ep 16 (Step 003220): Train loss 3.488, Val loss 5.474
# Ep 16 (Step 003225): Train loss 3.322, Val loss 5.477
# Ep 16 (Step 003230): Train loss 3.484, Val loss 5.493
# Ep 16 (Step 003235): Train loss 3.049, Val loss 5.489
# Ep 16 (Step 003240): Train loss 3.544, Val loss 5.494
# Ep 16 (Step 003245): Train loss 3.581, Val loss 5.510
# Ep 16 (Step 003250): Train loss 3.605, Val loss 5.487
# Ep 16 (Step 003255): Train loss 3.446, Val loss 5.478
# Ep 16 (Step 003260): Train loss 3.575, Val loss 5.472
# Ep 16 (Step 003265): Train loss 3.558, Val loss 5.426
# Ep 16 (Step 003270): Train loss 3.611, Val loss 5.435
# Ep 16 (Step 003275): Train loss 3.538, Val loss 5.486
# Ep 16 (Step 003280): Train loss 3.458, Val loss 5.504
# Ep 16 (Step 003285): Train loss 3.485, Val loss 5.485
# Ep 16 (Step 003290): Train loss 3.532, Val loss 5.477
# Ep 16 (Step 003295): Train loss 3.481, Val loss 5.477
# Ep 16 (Step 003300): Train loss 3.373, Val loss 5.469
# Ep 16 (Step 003305): Train loss 3.523, Val loss 5.475
# Ep 16 (Step 003310): Train loss 3.531, Val loss 5.471
# Ep 16 (Step 003315): Train loss 3.553, Val loss 5.459
# Ep 16 (Step 003320): Train loss 3.326, Val loss 5.467
# Ep 16 (Step 003325): Train loss 3.462, Val loss 5.464
# Ep 16 (Step 003330): Train loss 3.444, Val loss 5.472
# Ep 16 (Step 003335): Train loss 3.370, Val loss 5.493
# Ep 16 (Step 003340): Train loss 3.212, Val loss 5.444
# Ep 16 (Step 003345): Train loss 3.310, Val loss 5.476
# Ep 16 (Step 003350): Train loss 3.311, Val loss 5.431
# Ep 16 (Step 003355): Train loss 3.618, Val loss 5.410
# Ep 16 (Step 003360): Train loss 3.197, Val loss 5.434
# Ep 16 (Step 003365): Train loss 3.673, Val loss 5.418
# Ep 16 (Step 003370): Train loss 3.390, Val loss 5.434
# Ep 16 (Step 003375): Train loss 3.464, Val loss 5.418
# Ep 16 (Step 003380): Train loss 3.340, Val loss 5.427
# Ep 16 (Step 003385): Train loss 3.363, Val loss 5.444
# Ep 16 (Step 003390): Train loss 3.505, Val loss 5.436
# וילכו בני ישראל אל ה מקום אשר צוה יהוה . ו ידבר יהוה אל משה לאמר . ו אהרן ו אהרן ו אהרן אל משה אל משה לאמר . ו אהרן ו אהרן ו אהרן ו אהרן את בני ישראל ו אהרן ו אהרן ו אהרן ו אהרן את משה ו את משה ו אהרן ו
# Ep 17 (Step 003395): Train loss 3.287, Val loss 5.433
# Ep 17 (Step 003400): Train loss 3.418, Val loss 5.427
# Ep 17 (Step 003405): Train loss 3.357, Val loss 5.493
# Ep 17 (Step 003410): Train loss 3.363, Val loss 5.491
# Ep 17 (Step 003415): Train loss 3.191, Val loss 5.443
# Ep 17 (Step 003420): Train loss 3.346, Val loss 5.446
# Ep 17 (Step 003425): Train loss 3.325, Val loss 5.467
# Ep 17 (Step 003430): Train loss 3.484, Val loss 5.487
# Ep 17 (Step 003435): Train loss 2.913, Val loss 5.461
# Ep 17 (Step 003440): Train loss 3.580, Val loss 5.427
# Ep 17 (Step 003445): Train loss 3.228, Val loss 5.451
# Ep 17 (Step 003450): Train loss 3.255, Val loss 5.473
# Ep 17 (Step 003455): Train loss 3.395, Val loss 5.468
# Ep 17 (Step 003460): Train loss 3.467, Val loss 5.469
# Ep 17 (Step 003465): Train loss 3.206, Val loss 5.459
# Ep 17 (Step 003470): Train loss 3.163, Val loss 5.470
# Ep 17 (Step 003475): Train loss 3.361, Val loss 5.455
# Ep 17 (Step 003480): Train loss 3.534, Val loss 5.499
# Ep 17 (Step 003485): Train loss 3.087, Val loss 5.486
# Ep 17 (Step 003490): Train loss 3.130, Val loss 5.474
# Ep 17 (Step 003495): Train loss 3.418, Val loss 5.492
# Ep 17 (Step 003500): Train loss 3.246, Val loss 5.500
# Ep 17 (Step 003505): Train loss 3.328, Val loss 5.504
# Ep 17 (Step 003510): Train loss 3.426, Val loss 5.489
# Ep 17 (Step 003515): Train loss 3.214, Val loss 5.506
# Ep 17 (Step 003520): Train loss 3.278, Val loss 5.531
# Ep 17 (Step 003525): Train loss 3.342, Val loss 5.501
# Ep 17 (Step 003530): Train loss 3.355, Val loss 5.487
# Ep 17 (Step 003535): Train loss 3.450, Val loss 5.493
# Ep 17 (Step 003540): Train loss 3.314, Val loss 5.498
# Ep 17 (Step 003545): Train loss 3.236, Val loss 5.486
# Ep 17 (Step 003550): Train loss 3.287, Val loss 5.478
# Ep 17 (Step 003555): Train loss 3.200, Val loss 5.496
# Ep 17 (Step 003560): Train loss 3.239, Val loss 5.503
# Ep 17 (Step 003565): Train loss 2.981, Val loss 5.528
# Ep 17 (Step 003570): Train loss 3.474, Val loss 5.496
# Ep 17 (Step 003575): Train loss 3.393, Val loss 5.506
# Ep 17 (Step 003580): Train loss 3.250, Val loss 5.499
# Ep 17 (Step 003585): Train loss 3.287, Val loss 5.491
# Ep 17 (Step 003590): Train loss 3.260, Val loss 5.506
# Ep 17 (Step 003595): Train loss 3.206, Val loss 5.495
# Ep 17 (Step 003600): Train loss 3.101, Val loss 5.508
# וילכו בני ישראל אל ה מקום אשר צוה יהוה אל משה לאמר . ו אהרן את בני ישראל את משה את ה עם ה עם ה עם ה עם ה עם ה עם ו את ה עם ו את ה עם ה עם ו את ה עם ה עם ו את ה עם ו את ה
# Ep 18 (Step 003605): Train loss 3.414, Val loss 5.496
# Ep 18 (Step 003610): Train loss 3.289, Val loss 5.511
# Ep 18 (Step 003615): Train loss 3.226, Val loss 5.529
# Ep 18 (Step 003620): Train loss 2.961, Val loss 5.537
# Ep 18 (Step 003625): Train loss 2.778, Val loss 5.511
# Ep 18 (Step 003630): Train loss 3.262, Val loss 5.498
# Ep 18 (Step 003635): Train loss 3.299, Val loss 5.534
# Ep 18 (Step 003640): Train loss 3.029, Val loss 5.509
# Ep 18 (Step 003645): Train loss 3.341, Val loss 5.504
# Ep 18 (Step 003650): Train loss 3.226, Val loss 5.527
# Ep 18 (Step 003655): Train loss 3.398, Val loss 5.517
# Ep 18 (Step 003660): Train loss 3.414, Val loss 5.499
# Ep 18 (Step 003665): Train loss 3.133, Val loss 5.510
# Ep 18 (Step 003670): Train loss 3.107, Val loss 5.521
# Ep 18 (Step 003675): Train loss 3.224, Val loss 5.528
# Ep 18 (Step 003680): Train loss 2.744, Val loss 5.507
# Ep 18 (Step 003685): Train loss 3.148, Val loss 5.494
# Ep 18 (Step 003690): Train loss 3.125, Val loss 5.504
# Ep 18 (Step 003695): Train loss 3.220, Val loss 5.525
# Ep 18 (Step 003700): Train loss 3.033, Val loss 5.538
# Ep 18 (Step 003705): Train loss 3.130, Val loss 5.543
# Ep 18 (Step 003710): Train loss 2.938, Val loss 5.535
# Ep 18 (Step 003715): Train loss 3.141, Val loss 5.549
# Ep 18 (Step 003720): Train loss 3.202, Val loss 5.524
# Ep 18 (Step 003725): Train loss 3.147, Val loss 5.517
# Ep 18 (Step 003730): Train loss 3.115, Val loss 5.525
# Ep 18 (Step 003735): Train loss 3.222, Val loss 5.550
# Ep 18 (Step 003740): Train loss 2.984, Val loss 5.551
# Ep 18 (Step 003745): Train loss 3.293, Val loss 5.556
# Ep 18 (Step 003750): Train loss 3.020, Val loss 5.521
# Ep 18 (Step 003755): Train loss 3.178, Val loss 5.489
# Ep 18 (Step 003760): Train loss 3.250, Val loss 5.530
# Ep 18 (Step 003765): Train loss 2.664, Val loss 5.563
# Ep 18 (Step 003770): Train loss 3.248, Val loss 5.551
# Ep 18 (Step 003775): Train loss 3.152, Val loss 5.520
# Ep 18 (Step 003780): Train loss 3.158, Val loss 5.549
# Ep 18 (Step 003785): Train loss 3.018, Val loss 5.557
# Ep 18 (Step 003790): Train loss 3.151, Val loss 5.557
# Ep 18 (Step 003795): Train loss 3.209, Val loss 5.531
# Ep 18 (Step 003800): Train loss 2.994, Val loss 5.540
# Ep 18 (Step 003805): Train loss 3.106, Val loss 5.572
# Ep 18 (Step 003810): Train loss 3.246, Val loss 5.581
# Ep 18 (Step 003815): Train loss 3.188, Val loss 5.547
# וילכו בני ישראל אל ה מקום אשר צוה יהוה אל משה לאמר . ו אהרן את בני ישראל את ה לוים לפני יהוה אל משה ו את ה לוים ה לוים אשר על ה לוים . ו את ה לוים אשר על ה קרב ו את ה מזבח ה חלב ה כהן על ה חלב אשר
# Ep 19 (Step 003820): Train loss 2.956, Val loss 5.509
# Ep 19 (Step 003825): Train loss 3.148, Val loss 5.529
# Ep 19 (Step 003830): Train loss 3.198, Val loss 5.534
# Ep 19 (Step 003835): Train loss 3.011, Val loss 5.526
# Ep 19 (Step 003840): Train loss 3.032, Val loss 5.557
# Ep 19 (Step 003845): Train loss 2.756, Val loss 5.597
# Ep 19 (Step 003850): Train loss 3.248, Val loss 5.605
# Ep 19 (Step 003855): Train loss 2.876, Val loss 5.580
# Ep 19 (Step 003860): Train loss 2.939, Val loss 5.555
# Ep 19 (Step 003865): Train loss 3.029, Val loss 5.533
# Ep 19 (Step 003870): Train loss 2.928, Val loss 5.551
# Ep 19 (Step 003875): Train loss 3.088, Val loss 5.548
# Ep 19 (Step 003880): Train loss 2.736, Val loss 5.540
# Ep 19 (Step 003885): Train loss 3.243, Val loss 5.510
# Ep 19 (Step 003890): Train loss 3.072, Val loss 5.509
# Ep 19 (Step 003895): Train loss 3.027, Val loss 5.548
# Ep 19 (Step 003900): Train loss 3.001, Val loss 5.554
# Ep 19 (Step 003905): Train loss 3.243, Val loss 5.550
# Ep 19 (Step 003910): Train loss 2.988, Val loss 5.531
# Ep 19 (Step 003915): Train loss 3.063, Val loss 5.542
# Ep 19 (Step 003920): Train loss 2.963, Val loss 5.547
# Ep 19 (Step 003925): Train loss 3.153, Val loss 5.555
# Ep 19 (Step 003930): Train loss 3.246, Val loss 5.574
# Ep 19 (Step 003935): Train loss 3.098, Val loss 5.567
# Ep 19 (Step 003940): Train loss 2.972, Val loss 5.543
# Ep 19 (Step 003945): Train loss 2.908, Val loss 5.560
# Ep 19 (Step 003950): Train loss 3.022, Val loss 5.572
# Ep 19 (Step 003955): Train loss 2.956, Val loss 5.579
# Ep 19 (Step 003960): Train loss 2.998, Val loss 5.562
# Ep 19 (Step 003965): Train loss 2.780, Val loss 5.549
# Ep 19 (Step 003970): Train loss 2.755, Val loss 5.550
# Ep 19 (Step 003975): Train loss 3.138, Val loss 5.574
# Ep 19 (Step 003980): Train loss 2.866, Val loss 5.587
# Ep 19 (Step 003985): Train loss 3.166, Val loss 5.575
# Ep 19 (Step 003990): Train loss 3.191, Val loss 5.556
# Ep 19 (Step 003995): Train loss 2.985, Val loss 5.561
# Ep 19 (Step 004000): Train loss 3.090, Val loss 5.581
# Ep 19 (Step 004005): Train loss 3.138, Val loss 5.579
# Ep 19 (Step 004010): Train loss 3.047, Val loss 5.553
# Ep 19 (Step 004015): Train loss 3.032, Val loss 5.536
# Ep 19 (Step 004020): Train loss 2.908, Val loss 5.552
# Ep 19 (Step 004025): Train loss 2.873, Val loss 5.583
# וילכו בני ישראל אל ה מקום אשר צוה יהוה את ה זה ו את ה לוים לפני יהוה . ו את ה לוים ו את ה קרב ו את ה לוים החטאת ו את ה לוים . ו את ה קרב ו את ה מזבח ו את ה מזבח ה מזבח ו את ה מזבח ו
# Ep 20 (Step 004030): Train loss 2.746, Val loss 5.566
# Ep 20 (Step 004035): Train loss 3.111, Val loss 5.524
# Ep 20 (Step 004040): Train loss 2.787, Val loss 5.549
# Ep 20 (Step 004045): Train loss 2.972, Val loss 5.594
# Ep 20 (Step 004050): Train loss 2.881, Val loss 5.579
# Ep 20 (Step 004055): Train loss 2.870, Val loss 5.569
# Ep 20 (Step 004060): Train loss 2.988, Val loss 5.590
# Ep 20 (Step 004065): Train loss 2.562, Val loss 5.612
# Ep 20 (Step 004070): Train loss 3.100, Val loss 5.603
# Ep 20 (Step 004075): Train loss 2.913, Val loss 5.620
# Ep 20 (Step 004080): Train loss 2.920, Val loss 5.624
# Ep 20 (Step 004085): Train loss 2.899, Val loss 5.605
# Ep 20 (Step 004090): Train loss 3.094, Val loss 5.607
# Ep 20 (Step 004095): Train loss 2.761, Val loss 5.611
# Ep 20 (Step 004100): Train loss 2.779, Val loss 5.618
# Ep 20 (Step 004105): Train loss 2.926, Val loss 5.627
# Ep 20 (Step 004110): Train loss 2.885, Val loss 5.621
# Ep 20 (Step 004115): Train loss 2.601, Val loss 5.606
# Ep 20 (Step 004120): Train loss 2.484, Val loss 5.611
# Ep 20 (Step 004125): Train loss 2.915, Val loss 5.617
# Ep 20 (Step 004130): Train loss 2.692, Val loss 5.617
# Ep 20 (Step 004135): Train loss 3.007, Val loss 5.605
# Ep 20 (Step 004140): Train loss 2.520, Val loss 5.623
# Ep 20 (Step 004145): Train loss 2.715, Val loss 5.611
# Ep 20 (Step 004150): Train loss 3.007, Val loss 5.590
# ...
# Ep 44 (Step 009245): Train loss 0.868, Val loss 6.996
# Ep 44 (Step 009250): Train loss 0.876, Val loss 7.071
# Ep 44 (Step 009255): Train loss 0.870, Val loss 7.095
# Ep 44 (Step 009260): Train loss 0.846, Val loss 7.083
# Ep 44 (Step 009265): Train loss 0.801, Val loss 7.051
# Ep 44 (Step 009270): Train loss 0.852, Val loss 7.098
# Ep 44 (Step 009275): Train loss 0.900, Val loss 7.098
# Ep 44 (Step 009280): Train loss 0.841, Val loss 7.041
# Ep 44 (Step 009285): Train loss 0.862, Val loss 7.054
# Ep 44 (Step 009290): Train loss 0.829, Val loss 7.065
# Ep 44 (Step 009295): Train loss 0.908, Val loss 7.062
# Ep 44 (Step 009300): Train loss 0.807, Val loss 7.064
# Ep 44 (Step 009305): Train loss 0.893, Val loss 7.074
# Ep 44 (Step 009310): Train loss 0.866, Val loss 7.054
# Ep 44 (Step 009315): Train loss 0.943, Val loss 7.126
# Ep 44 (Step 009320): Train loss 0.816, Val loss 7.129
# Ep 44 (Step 009325): Train loss 0.931, Val loss 7.078
# וילכו בני ישראל אל ה מקום אשר צוה יהוה את ו את עון ו את עון ל אהרן ו את ו את ו את ו את בני אהרן ו את אהרן את אהרן ו את אהרן ו את אהרן ו את אהרן ו את מעיל ו את ה חלב ו . ו את ה כיר ו
# Ep 45 (Step 009330): Train loss 0.830, Val loss 7.047
# Ep 45 (Step 009335): Train loss 0.824, Val loss 7.075
# Ep 45 (Step 009340): Train loss 0.843, Val loss 7.102
# Ep 45 (Step 009345): Train loss 0.863, Val loss 7.111
# Ep 45 (Step 009350): Train loss 0.798, Val loss 7.120
# Ep 45 (Step 009355): Train loss 0.884, Val loss 7.166
# Ep 45 (Step 009360): Train loss 0.819, Val loss 7.179
# Ep 45 (Step 009365): Train loss 0.803, Val loss 7.097
# Ep 45 (Step 009370): Train loss 0.789, Val loss 7.080
# Ep 45 (Step 009375): Train loss 0.908, Val loss 7.083
# Ep 45 (Step 009380): Train loss 0.879, Val loss 7.092
# Ep 45 (Step 009385): Train loss 0.772, Val loss 7.131
# Ep 45 (Step 009390): Train loss 0.851, Val loss 7.092
# Ep 45 (Step 009395): Train loss 0.725, Val loss 7.066
# Ep 45 (Step 009400): Train loss 0.816, Val loss 7.051
# Ep 45 (Step 009405): Train loss 0.859, Val loss 7.079
# Ep 45 (Step 009410): Train loss 0.872, Val loss 7.147
# Ep 45 (Step 009415): Train loss 0.909, Val loss 7.125
# Ep 45 (Step 009420): Train loss 0.845, Val loss 7.096
# Ep 45 (Step 009425): Train loss 0.845, Val loss 7.103
# Ep 45 (Step 009430): Train loss 0.825, Val loss 7.129
# Ep 45 (Step 009435): Train loss 0.882, Val loss 7.148
# Ep 45 (Step 009440): Train loss 0.796, Val loss 7.117
# Ep 45 (Step 009445): Train loss 0.965, Val loss 7.163
# Ep 45 (Step 009450): Train loss 0.895, Val loss 7.157
# Ep 45 (Step 009455): Train loss 0.909, Val loss 7.117
# Ep 45 (Step 009460): Train loss 0.716, Val loss 7.141
# Ep 45 (Step 009465): Train loss 0.807, Val loss 7.158
# Ep 45 (Step 009470): Train loss 0.811, Val loss 7.144
# Ep 45 (Step 009475): Train loss 0.803, Val loss 7.137
# Ep 45 (Step 009480): Train loss 0.895, Val loss 7.144
# Ep 45 (Step 009485): Train loss 0.801, Val loss 7.112
# Ep 45 (Step 009490): Train loss 0.852, Val loss 7.093
# Ep 45 (Step 009495): Train loss 0.804, Val loss 7.129
# Ep 45 (Step 009500): Train loss 0.817, Val loss 7.118
# Ep 45 (Step 009505): Train loss 0.756, Val loss 7.094
# Ep 45 (Step 009510): Train loss 0.844, Val loss 7.134
# Ep 45 (Step 009515): Train loss 0.792, Val loss 7.181
# Ep 45 (Step 009520): Train loss 0.734, Val loss 7.168
# Ep 45 (Step 009525): Train loss 0.766, Val loss 7.128
# Ep 45 (Step 009530): Train loss 0.814, Val loss 7.142
# Ep 45 (Step 009535): Train loss 0.790, Val loss 7.146
# וילכו בני ישראל אל ה מקום אשר ילקטו מ בני ישראל . ו יאמר אל אדני כי אין דבר אלי כם דבר אל ה אמן . ו יפנו ו ית נו אלי ו יאמר אל ה עם ה נער אנכי נצב על ה נער אל ה צאן את ה נער . ו את ה ארץ ו
# Ep 46 (Step 009540): Train loss 0.806, Val loss 7.131
# Ep 46 (Step 009545): Train loss 0.783, Val loss 7.137
# Ep 46 (Step 009550): Train loss 0.695, Val loss 7.127
# Ep 46 (Step 009555): Train loss 0.844, Val loss 7.121
# Ep 46 (Step 009560): Train loss 0.779, Val loss 7.141
# Ep 46 (Step 009565): Train loss 0.800, Val loss 7.124
# Ep 46 (Step 009570): Train loss 0.686, Val loss 7.112
# Ep 46 (Step 009575): Train loss 0.875, Val loss 7.140
# Ep 46 (Step 009580): Train loss 0.861, Val loss 7.134
# Ep 46 (Step 009585): Train loss 0.792, Val loss 7.133
# Ep 46 (Step 009590): Train loss 0.643, Val loss 7.140
# Ep 46 (Step 009595): Train loss 0.770, Val loss 7.162
# Ep 46 (Step 009600): Train loss 0.799, Val loss 7.123
# Ep 46 (Step 009605): Train loss 0.757, Val loss 7.114
# Ep 46 (Step 009610): Train loss 0.814, Val loss 7.163
# Ep 46 (Step 009615): Train loss 0.806, Val loss 7.180
# Ep 46 (Step 009620): Train loss 0.790, Val loss 7.135
# Ep 46 (Step 009625): Train loss 0.768, Val loss 7.146
# Ep 46 (Step 009630): Train loss 0.757, Val loss 7.127
# Ep 46 (Step 009635): Train loss 0.801, Val loss 7.085
# Ep 46 (Step 009640): Train loss 0.848, Val loss 7.129
# Ep 46 (Step 009645): Train loss 0.922, Val loss 7.195
# Ep 46 (Step 009650): Train loss 0.813, Val loss 7.214
# Ep 46 (Step 009655): Train loss 0.681, Val loss 7.194
# Ep 46 (Step 009660): Train loss 0.787, Val loss 7.181
# Ep 46 (Step 009665): Train loss 0.804, Val loss 7.180
# Ep 46 (Step 009670): Train loss 0.810, Val loss 7.187
# Ep 46 (Step 009675): Train loss 0.871, Val loss 7.158
# Ep 46 (Step 009680): Train loss 0.813, Val loss 7.144
# Ep 46 (Step 009685): Train loss 0.723, Val loss 7.167
# Ep 46 (Step 009690): Train loss 0.765, Val loss 7.162
# Ep 46 (Step 009695): Train loss 0.786, Val loss 7.189
# Ep 46 (Step 009700): Train loss 0.824, Val loss 7.215
# Ep 46 (Step 009705): Train loss 0.817, Val loss 7.208
# Ep 46 (Step 009710): Train loss 0.774, Val loss 7.192
# Ep 46 (Step 009715): Train loss 0.713, Val loss 7.184
# Ep 46 (Step 009720): Train loss 0.691, Val loss 7.215
# Ep 46 (Step 009725): Train loss 0.796, Val loss 7.200
# Ep 46 (Step 009730): Train loss 0.712, Val loss 7.204
# Ep 46 (Step 009735): Train loss 0.774, Val loss 7.179
# Ep 46 (Step 009740): Train loss 0.778, Val loss 7.145
# Ep 46 (Step 009745): Train loss 0.788, Val loss 7.174
# Ep 46 (Step 009750): Train loss 0.861, Val loss 7.193
# וילכו בני ישראל אל ה מקום אשר דבר אשר דבר ו . ו יאמר אל אדני כי אנכי הולך את ך ו את ו את ו את ה אתת י . ו את פני נו ו את ה אתת י כ חול ל ך ו את אדני . ו יאמר ה שמים ו יאמר אברהם את
# Ep 47 (Step 009755): Train loss 0.829, Val loss 7.175
# Ep 47 (Step 009760): Train loss 0.826, Val loss 7.196
# Ep 47 (Step 009765): Train loss 0.740, Val loss 7.207
# Ep 47 (Step 009770): Train loss 0.726, Val loss 7.193
# Ep 47 (Step 009775): Train loss 0.811, Val loss 7.198
# Ep 47 (Step 009780): Train loss 0.769, Val loss 7.182
# Ep 47 (Step 009785): Train loss 0.777, Val loss 7.192
# Ep 47 (Step 009790): Train loss 0.769, Val loss 7.202
# Ep 47 (Step 009795): Train loss 0.776, Val loss 7.208
# Ep 47 (Step 009800): Train loss 0.713, Val loss 7.239
# Ep 47 (Step 009805): Train loss 0.797, Val loss 7.208
# Ep 47 (Step 009810): Train loss 0.739, Val loss 7.187
# Ep 47 (Step 009815): Train loss 0.719, Val loss 7.241
# Ep 47 (Step 009820): Train loss 0.729, Val loss 7.299
# Ep 47 (Step 009825): Train loss 0.691, Val loss 7.316
# Ep 47 (Step 009830): Train loss 0.802, Val loss 7.246
# Ep 47 (Step 009835): Train loss 0.783, Val loss 7.224
# Ep 47 (Step 009840): Train loss 0.789, Val loss 7.235
# Ep 47 (Step 009845): Train loss 0.735, Val loss 7.284
# Ep 47 (Step 009850): Train loss 0.779, Val loss 7.230
# Ep 47 (Step 009855): Train loss 0.644, Val loss 7.198
# Ep 47 (Step 009860): Train loss 0.760, Val loss 7.218
# Ep 47 (Step 009865): Train loss 0.776, Val loss 7.217
# Ep 47 (Step 009870): Train loss 0.770, Val loss 7.199
# Ep 47 (Step 009875): Train loss 0.758, Val loss 7.244
# Ep 47 (Step 009880): Train loss 0.766, Val loss 7.255
# Ep 47 (Step 009885): Train loss 0.775, Val loss 7.219
# Ep 47 (Step 009890): Train loss 0.783, Val loss 7.225
# Ep 47 (Step 009895): Train loss 0.750, Val loss 7.269
# Ep 47 (Step 009900): Train loss 0.773, Val loss 7.303
# Ep 47 (Step 009905): Train loss 0.767, Val loss 7.257
# Ep 47 (Step 009910): Train loss 0.788, Val loss 7.218
# Ep 47 (Step 009915): Train loss 0.795, Val loss 7.195
# Ep 47 (Step 009920): Train loss 0.740, Val loss 7.192
# Ep 47 (Step 009925): Train loss 0.712, Val loss 7.240
# Ep 47 (Step 009930): Train loss 0.801, Val loss 7.196
# Ep 47 (Step 009935): Train loss 0.811, Val loss 7.196
# Ep 47 (Step 009940): Train loss 0.694, Val loss 7.252
# Ep 47 (Step 009945): Train loss 0.745, Val loss 7.236
# Ep 47 (Step 009950): Train loss 0.759, Val loss 7.213
# Ep 47 (Step 009955): Train loss 0.789, Val loss 7.264
# Ep 47 (Step 009960): Train loss 0.791, Val loss 7.225
# וילכו בני ישראל אל ה מקום אשר אנכי לא הגדת ל אלהים ב זה כי אנכי מת ו . ו יאמר אלי נו מעט אתה ל הם ו ל י אדני למה זה ו נזיד עדשים ו את ה זה יצאנו עלי ה אנשים ה זה . ו יאמר אלי ו יאמר אלי אל אדני ו
# Ep 48 (Step 009965): Train loss 0.752, Val loss 7.163
# Ep 48 (Step 009970): Train loss 0.707, Val loss 7.234
# Ep 48 (Step 009975): Train loss 0.650, Val loss 7.248
# Ep 48 (Step 009980): Train loss 0.696, Val loss 7.252
# Ep 48 (Step 009985): Train loss 0.725, Val loss 7.252
# Ep 48 (Step 009990): Train loss 0.731, Val loss 7.220
# Ep 48 (Step 009995): Train loss 0.790, Val loss 7.241
# Ep 48 (Step 010000): Train loss 0.772, Val loss 7.291
# Ep 48 (Step 010005): Train loss 0.727, Val loss 7.317
# Ep 48 (Step 010010): Train loss 0.805, Val loss 7.244
# Ep 48 (Step 010015): Train loss 0.749, Val loss 7.279
# Ep 48 (Step 010020): Train loss 0.745, Val loss 7.335
# Ep 48 (Step 010025): Train loss 0.711, Val loss 7.307
# Ep 48 (Step 010030): Train loss 0.658, Val loss 7.236
# Ep 48 (Step 010035): Train loss 0.588, Val loss 7.216
# Ep 48 (Step 010040): Train loss 0.703, Val loss 7.260
# Ep 48 (Step 010045): Train loss 0.773, Val loss 7.257
# Ep 48 (Step 010050): Train loss 0.676, Val loss 7.274
# Ep 48 (Step 010055): Train loss 0.730, Val loss 7.251
# Ep 48 (Step 010060): Train loss 0.718, Val loss 7.261
# Ep 48 (Step 010065): Train loss 0.779, Val loss 7.294
# Ep 48 (Step 010070): Train loss 0.696, Val loss 7.268
# Ep 48 (Step 010075): Train loss 0.654, Val loss 7.254
# Ep 48 (Step 010080): Train loss 0.728, Val loss 7.291
# Ep 48 (Step 010085): Train loss 0.692, Val loss 7.312
# Ep 48 (Step 010090): Train loss 0.794, Val loss 7.305
# Ep 48 (Step 010095): Train loss 0.707, Val loss 7.266
# Ep 48 (Step 010100): Train loss 0.735, Val loss 7.282
# Ep 48 (Step 010105): Train loss 0.697, Val loss 7.276
# Ep 48 (Step 010110): Train loss 0.636, Val loss 7.268
# Ep 48 (Step 010115): Train loss 0.729, Val loss 7.285
# Ep 48 (Step 010120): Train loss 0.757, Val loss 7.227
# Ep 48 (Step 010125): Train loss 0.749, Val loss 7.205
# Ep 48 (Step 010130): Train loss 0.803, Val loss 7.242
# Ep 48 (Step 010135): Train loss 0.766, Val loss 7.242
# Ep 48 (Step 010140): Train loss 0.710, Val loss 7.214
# Ep 48 (Step 010145): Train loss 0.728, Val loss 7.250
# Ep 48 (Step 010150): Train loss 0.715, Val loss 7.300
# Ep 48 (Step 010155): Train loss 0.735, Val loss 7.295
# Ep 48 (Step 010160): Train loss 0.689, Val loss 7.251
# Ep 48 (Step 010165): Train loss 0.732, Val loss 7.290
# Ep 48 (Step 010170): Train loss 0.732, Val loss 7.293
# Ep 48 (Step 010175): Train loss 0.652, Val loss 7.318
# וילכו בני ישראל אל ה מקום אשר צוה יהוה . ו ידבר משה אל אהרן ו אמרת אלהם ב גדי כם להקריב את ה עדה ו את ה דם על ה דם ה אש לפני יהוה . ו את ה דם על ה דם ה קרב ו את ה כבד על ה כסלים אשר על ה
# Ep 49 (Step 010180): Train loss 0.647, Val loss 7.301
# Ep 49 (Step 010185): Train loss 0.731, Val loss 7.291
# Ep 49 (Step 010190): Train loss 0.652, Val loss 7.284
# Ep 49 (Step 010195): Train loss 0.690, Val loss 7.303
# Ep 49 (Step 010200): Train loss 0.707, Val loss 7.355
# Ep 49 (Step 010205): Train loss 0.693, Val loss 7.305
# Ep 49 (Step 010210): Train loss 0.684, Val loss 7.306
# Ep 49 (Step 010215): Train loss 0.643, Val loss 7.319
# Ep 49 (Step 010220): Train loss 0.636, Val loss 7.346
# Ep 49 (Step 010225): Train loss 0.656, Val loss 7.368
# Ep 49 (Step 010230): Train loss 0.708, Val loss 7.329
# Ep 49 (Step 010235): Train loss 0.634, Val loss 7.269
# Ep 49 (Step 010240): Train loss 0.640, Val loss 7.310
# Ep 49 (Step 010245): Train loss 0.691, Val loss 7.292
# Ep 49 (Step 010250): Train loss 0.722, Val loss 7.300
# Ep 49 (Step 010255): Train loss 0.577, Val loss 7.316
# Ep 49 (Step 010260): Train loss 0.661, Val loss 7.318
# Ep 49 (Step 010265): Train loss 0.719, Val loss 7.335
# Ep 49 (Step 010270): Train loss 0.781, Val loss 7.321
# Ep 49 (Step 010275): Train loss 0.736, Val loss 7.262
# Ep 49 (Step 010280): Train loss 0.599, Val loss 7.257
# Ep 49 (Step 010285): Train loss 0.689, Val loss 7.292
# Ep 49 (Step 010290): Train loss 0.730, Val loss 7.291
# Ep 49 (Step 010295): Train loss 0.645, Val loss 7.271
# Ep 49 (Step 010300): Train loss 0.678, Val loss 7.301
# Ep 49 (Step 010305): Train loss 0.743, Val loss 7.312
# Ep 49 (Step 010310): Train loss 0.649, Val loss 7.324
# Ep 49 (Step 010315): Train loss 0.727, Val loss 7.316
# Ep 49 (Step 010320): Train loss 0.671, Val loss 7.311
# Ep 49 (Step 010325): Train loss 0.716, Val loss 7.338
# Ep 49 (Step 010330): Train loss 0.673, Val loss 7.364
# Ep 49 (Step 010335): Train loss 0.716, Val loss 7.370
# Ep 49 (Step 010340): Train loss 0.626, Val loss 7.354
# Ep 49 (Step 010345): Train loss 0.745, Val loss 7.345
# Ep 49 (Step 010350): Train loss 0.675, Val loss 7.333
# Ep 49 (Step 010355): Train loss 0.697, Val loss 7.296
# Ep 49 (Step 010360): Train loss 0.674, Val loss 7.304
# Ep 49 (Step 010365): Train loss 0.640, Val loss 7.327
# Ep 49 (Step 010370): Train loss 0.666, Val loss 7.306
# Ep 49 (Step 010375): Train loss 0.695, Val loss 7.310
# Ep 49 (Step 010380): Train loss 0.700, Val loss 7.320
# Ep 49 (Step 010385): Train loss 0.615, Val loss 7.343
# וילכו בני ישראל אל ה מקום אשר אנכי לא הגדת ל כם ו הייתם לא תקפו לב ו ממנ י ו . ו אל היכם ו אל היכם . ו אל ה דבר אשר אני יהוה לעשות ה מן ה עם על פני ה אדמה לא ישתה את משמרת ה בשר ו את כם מ ארץ
# Ep 50 (Step 010390): Train loss 0.591, Val loss 7.350
# Ep 50 (Step 010395): Train loss 0.657, Val loss 7.353
# Ep 50 (Step 010400): Train loss 0.732, Val loss 7.399
# Ep 50 (Step 010405): Train loss 0.679, Val loss 7.444
# Ep 50 (Step 010410): Train loss 0.645, Val loss 7.345
# Ep 50 (Step 010415): Train loss 0.649, Val loss 7.290
# Ep 50 (Step 010420): Train loss 0.677, Val loss 7.361
# Ep 50 (Step 010425): Train loss 0.632, Val loss 7.335
# Ep 50 (Step 010430): Train loss 0.590, Val loss 7.368
# Ep 50 (Step 010435): Train loss 0.711, Val loss 7.346
# Ep 50 (Step 010440): Train loss 0.662, Val loss 7.324
# Ep 50 (Step 010445): Train loss 0.641, Val loss 7.331
# Ep 50 (Step 010450): Train loss 0.738, Val loss 7.344
# Ep 50 (Step 010455): Train loss 0.744, Val loss 7.375
# Ep 50 (Step 010460): Train loss 0.606, Val loss 7.387
# Ep 50 (Step 010465): Train loss 0.724, Val loss 7.363
# Ep 50 (Step 010470): Train loss 0.711, Val loss 7.376
# Ep 50 (Step 010475): Train loss 0.578, Val loss 7.422
# Ep 50 (Step 010480): Train loss 0.611, Val loss 7.421
# Ep 50 (Step 010485): Train loss 0.780, Val loss 7.370
# Ep 50 (Step 010490): Train loss 0.631, Val loss 7.331
# Ep 50 (Step 010495): Train loss 0.657, Val loss 7.325
# Ep 50 (Step 010500): Train loss 0.645, Val loss 7.346
# Ep 50 (Step 010505): Train loss 0.666, Val loss 7.413
# Ep 50 (Step 010510): Train loss 0.694, Val loss 7.462
# Ep 50 (Step 010515): Train loss 0.619, Val loss 7.399
# Ep 50 (Step 010520): Train loss 0.658, Val loss 7.335
# Ep 50 (Step 010525): Train loss 0.662, Val loss 7.343
# Ep 50 (Step 010530): Train loss 0.712, Val loss 7.385
# Ep 50 (Step 010535): Train loss 0.681, Val loss 7.387
# Ep 50 (Step 010540): Train loss 0.720, Val loss 7.374
# Ep 50 (Step 010545): Train loss 0.694, Val loss 7.412
# Ep 50 (Step 010550): Train loss 0.635, Val loss 7.416
# Ep 50 (Step 010555): Train loss 0.607, Val loss 7.371
# Ep 50 (Step 010560): Train loss 0.746, Val loss 7.349
# Ep 50 (Step 010565): Train loss 0.591, Val loss 7.382
# Ep 50 (Step 010570): Train loss 0.749, Val loss 7.370
# Ep 50 (Step 010575): Train loss 0.609, Val loss 7.385
# Ep 50 (Step 010580): Train loss 0.601, Val loss 7.379
# Ep 50 (Step 010585): Train loss 0.616, Val loss 7.342
# Ep 50 (Step 010590): Train loss 0.722, Val loss 7.356
# Ep 50 (Step 010595): Train loss 0.622, Val loss 7.381
# וילכו בני ישראל אל ה מקום אשר אנכי לא ידעתי כי אני יהוה אל היכם מ עם ה זה . ו יאמר יהוה אל משה אל אהרן אל משה לאמר ה עם כי אם לא שלח את ה זה ל עם ה עם ה עם ה זה ב כל ה עם ו הנה אנכי אדבר ו
